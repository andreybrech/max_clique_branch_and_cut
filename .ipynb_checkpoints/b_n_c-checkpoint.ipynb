# %% [raw]
# def is_int_solution_old():
#     """
#     True - if all variables int
#     False if even one of variables is float
#     """
#     global sol
#
#     sol_val = sol.get_objective_value()
#     if sol_val % 1 > eps and abs(sol_val % 1 - 1) > eps:
#         return False
#     for var in sol.iter_var_values():
#         if var[1] % 1 > eps and abs(var[1] % 1 - 1) > eps:
#             return False
#     return True

# %% [raw]
# def is_a_clique_old():
#     global sol, x_vars,g
#
#     var_values = [i[0].index+1 for i in sol.iter_var_values()] #заменить на x_vars уточнить
#     for i in range(len(var_values)):
#         for j in range(i+1, len(var_values)):
#             # print(vars[i], vars[j])
#             # print(g.V[vars[i]]['neighbours'])
#             if var_values[j] not in g.V[var_values[i]]['neighbours']:
#                 return False
#     return True

# %%
import numpy as np
from docplex.mp.model import Model
import copy
import random

eps = 1e-5

# %%
class Graph(object):
    """
    class of graph
    """
    
    def __init__(self):
        """
        V- множество вершин
        D - множество вершин, с возможностью их сортировки по степени
        colors - нужен только для покраски по вершинам
        """
        self.V = {}
        self.D = [] 
        self._D_sorted = False
        self.used_colors = set()
        self.coloring = dict()

    def add_edge(self,v1,v2):
        """
        add pair of vertexes to V
        add each other to neigbours
        """
        self._add_vertex_to_neighbours(v1,v2)
        self._add_vertex_to_neighbours(v2,v1)
        
        return
    
    def add_vertex(self,v1):
        """
        add one vertex to V
        """
        
        if v1 in self.V: # если вершина есть в множестве, то все ок. Ее не надо добавлять
                         # МБ надо обновить ее степень?
#             v1.update_degree = len(self.neighbours(v1))
#             self.V[v1]['degree'] = self.degree(v1)
#             D[self.V[v1]['D_index'] ] = self.V[v1]['degree']
            print('vertex already in graph.Vertexes')
            
            return
        else:
            self.V[v1] = {}
            self.V[v1]['name'] = v1
            self.V[v1]['neighbours'] = set()
            self.V[v1]['degree'] = 0
            self.D.append(self.V[v1])
            self._D_sorted = False
            
            return
    
            
    def _add_vertex_to_neighbours(self,v1, v2):
        """
        add vertex v2 to neigbours of vertex v1
        """
        if v1 not in self.V:
            self.add_vertex(v1)
        if v2 in self.V[v1]['neighbours']:
            print('vertex already in neighbours')
            return
        self.V[v1]['neighbours'].add(v2)
        self.V[v1]['degree'] += 1
        self._D_sorted = False

        return
    
    def neighbours(self,v1):
        """
        print all neigbour names of chosed vertex
        """
        if v1 in self.V:
            return self.V[v1]['neighbours']
        else:
            print("no such vertex in graph")
            return None 
        
    def is_neighbour(self,vertex_name,neighbour_name):
        """
        vetrex - vertex name
        neighbout - neighbour name
        True if neighbour
        False if not neighbour
        """
        if neighbour_name in self.V[vertex_name]['neighbours']:
            return True
        return False
    
    
    def sort_vertex_by_degree(self):
        """
        sort vertexes: big degree is first
        """
        # добавить маркер сортер для массива Д для того, чтобы не сортировать сортированный Д
        if self._D_sorted :
            return
        self.D.sort(key= lambda input: input['degree'])
        self._D_sorted = True
        return

        
    
    def degree(self,v1):
        """
        return degree of chosen vertex
        """
        if v1 in self.V:
            return len(self.V[v1]['neighbours'])
        else:
            return None
        
            
    
    def clear_coloring(self):
        self.used_colors = set()
        self.coloring = dict()

        
    def recolor(self):
        """
        Использовать с candidates при ветвлении
        т.к в первоначальной окраске слишком много цветов
        скорее всего стоит красить не каждое ветвление, а мб только в начале
        """
    #     print('***recolor***')
        max_color = -1
        self.coloring = dict()
        for vertex_name in self.V:
            self.coloring[vertex_name] = None
        self.used_colors = dict()
        for vertex_name in self.V:
#             print('vertex_name',vertex_name)
#             print('used_Colors',self.used_colors)
            avalible_colors = set(self.used_colors.keys() )
            for neighbour_name in g.V[vertex_name]['neighbours']:
#                 print('N',neighbour_name, self.coloring[neighbour_name] ,)
                avalible_colors -= {self.coloring[neighbour_name]}
                if len( avalible_colors ) == 0:
                    break
            if len( avalible_colors ) == 0:
                max_color += 1 # color is index in candidates_coloring
                self.used_colors[max_color] = set()
                self.used_colors[max_color].add(vertex_name)
                self.coloring[vertex_name] = max_color

#             print('avalible_colors',avalible_colors)
            if len( avalible_colors ) != 0:
                for avalible_color in avalible_colors:
                    rand_avalible_color = avalible_color
                    break
                self.used_colors[rand_avalible_color].add(vertex_name)
                self.coloring[vertex_name] = rand_avalible_color
#             print('chosen_Color',self.coloring[vertex_name])
#         return used_colors,candidates_coloring

    def recolor_by_degree(self, rev = False):
            """
            Использовать с candidates при ветвлении
            т.к в первоначальной окраске слишком много цветов
            скорее всего стоит красить не каждое ветвление, а мб только в начале
            """
        #     print('***recolor***')    
            self.sort_vertex_by_degree()
            max_color = -1
            self.coloring = dict()
            for vertex_name in self.V:
                self.coloring[vertex_name] = None
            self.used_colors = dict()
            if rev:
                D_range = range(len(self.D)-1,-1,-1)
            else:
                D_range = range(len(self.D))
            for vertex_index in D_range:
                vertex = self.D[vertex_index]
                vertex_name = vertex['name']
    #             print('vertex_name',vertex_name)
    #             print('used_Colors',self.used_colors)
                avalible_colors = set(self.used_colors.keys() )
                for neighbour_name in g.V[vertex_name]['neighbours']:
    #                 print('N',neighbour_name, self.coloring[neighbour_name] ,)
                    avalible_colors -= {self.coloring[neighbour_name]}
                    if len( avalible_colors ) == 0:
                        break
                if len( avalible_colors ) == 0:
                    max_color += 1 # color is index in candidates_coloring
                    self.used_colors[max_color] = set()
                    self.used_colors[max_color].add(vertex_name)
                    self.coloring[vertex_name] = max_color

    #             print('avalible_colors',avalible_colors)
                if len( avalible_colors ) != 0:
                    for avalible_color in avalible_colors:
                        rand_avalible_color = avalible_color
                        break
                    self.used_colors[rand_avalible_color].add(vertex_name)
                    self.coloring[vertex_name] = rand_avalible_color
    #             print('chosen_Color',self.coloring[vertex_name])
    
    def recolor_best_method(self):
        self.recolor()
        c1 = len(self.used_colors)
        self.clear_coloring()

        self.recolor_by_degree(rev = False)
        c2 = len(self.used_colors)
        self.clear_coloring()

        self.recolor_by_degree(rev = True)
        c3 = len(self.used_colors)
        self.clear_coloring()

        print('g.coloring()', c1)
        print('g.coloring_by_degree()', c2)
        print('g.coloring_by_degree_reverse()', c3)


        if c1 is min(c1,c2,c3):
            self.recolor()

        if c2 is min(c1,c2,c3):
            self.recolor_by_degree(rev = False)
        if c3 is min(c1,c2,c3):
            self.recolor_by_degree(rev = True)

        print('best g.colors', len(g.used_colors))

# %%
def read_dimacs_graph(file_path):
    '''
        Parse .col file and return graph object
    '''
    g = Graph()
    with open(file_path, 'r') as file:
        for line in file:
            if line.startswith('c'):  # graph description
                print(*line.split()[1:])
            # first line: p name num_of_vertices num_of_edges
            elif line.startswith('p'):
                p, name, vertices_num, edges_num = line.split()
                print('{0} {1} {2}'.format(name, vertices_num, edges_num))
            elif line.startswith('e'):
                _, v1, v2 = line.split()
                g.add_edge(int(v1),int(v2))
            else:
                continue
        return g

# %%
def candidates_recolor(candidates:set):
    """
    Использовать с candidates при ветвлении
    т.к в первоначальной окраске слишком много цветов
    скорее всего стоит красить не каждое ветвление, а мб только в начале
    """
#     print('***candidates_recolor***')
    max_color = 0
    candidates_coloring = dict()
    for vertex_name in candidates:
        candidates_coloring[vertex_name] = 0
    used_colors = {0: set()}
    for vertex_name in candidates:
#         print('vertex_name',vertex_name)
#         print('used_Colors',used_colors)
        neighbour_colors = set()
        for neighbour_name in g.V[vertex_name]['neighbours'].intersection(candidates):
#             print('N',neighbour_name, candidates_coloring[neighbour_name] , neighbour_name in candidates)
            neighbour_colors.add(candidates_coloring[neighbour_name])
            if len( neighbour_colors ) == len(used_colors):
#                 print('break')
                break
        if len( neighbour_colors ) == len(used_colors):
            max_color += 1 # color is index in candidates_coloring
            used_colors[max_color] = set()
            used_colors[max_color].add(vertex_name)
            candidates_coloring[vertex_name] = max_color
#             print(used_colors,candidates_coloring)
        
#         print('avalible_colors',avalible_colors)
        elif len( neighbour_colors ) < len(used_colors):
            avalible_colors = set(used_colors.keys()) - neighbour_colors
#             print('avalible_colors',avalible_colors)
            for avalible_color in avalible_colors:
                rand_avalible_color = avalible_color
                break
            used_colors[rand_avalible_color].add(vertex_name)
            candidates_coloring[vertex_name] = rand_avalible_color
#         print('chosen_Color',candidates_coloring[vertex_name])
    if len(candidates_coloring) != len(candidates):
        raise NameError('Not all verticies colored')
    return used_colors,candidates_coloring

def candidates_recolor_degree(candidates:set, rev = False):
    """
    Использовать с candidates при ветвлении
    т.к в первоначальной окраске слишком много цветов
    скорее всего стоит красить не каждое ветвление, а мб только в начале
    """
#     print('***candidates_recolor
    candidates_degree_order = list(candidates)
    candidates_degree_order.sort(key= lambda input: g.V[input]['degree'], reverse = rev)
    max_color = -1
    candidates_coloring = dict()
    for vertex_name in candidates:
        candidates_coloring[vertex_name] = None
    used_colors = dict()
    for vertex_name in candidates_degree_order:
#         print('vertex_name',vertex_name)
#         print('used_Colors',used_colors)
        avalible_colors = set(used_colors.keys() )
        for neighbour_name in g.V[vertex_name]['neighbours'].intersection(candidates):
#             print('N',neighbour_name, candidates_coloring[neighbour_name] , neighbour_name in candidates)
            avalible_colors -= {candidates_coloring[neighbour_name]}
            if len( avalible_colors ) == 0:
                break
        if len( avalible_colors ) == 0:
            max_color += 1 # color is index in candidates_coloring
            used_colors[max_color] = set()
            used_colors[max_color].add(vertex_name)
            candidates_coloring[vertex_name] = max_color
        
#         print('avalible_colors',avalible_colors)
        if len( avalible_colors ) != 0:
            for avalible_color in avalible_colors:
                rand_avalible_color = avalible_color
                break
            used_colors[rand_avalible_color].add(vertex_name)
            candidates_coloring[vertex_name] = rand_avalible_color
#         print('chosen_Color',candidates_coloring[vertex_name])
    return used_colors,candidates_coloring

# %%
def find_candidates(vertex_to_clique = None):
    """
    если клика пустая создает множество из всех вершин графа
    если не пустая выдает ошибку - использовать update_candidates
    """
    global clique, candidates
    
    if len(clique) == 0:
        candidates = set( g.V.keys() )
    else:
        raise NameError('len(clique) =! 0. Use update_candidates')

    return candidates

# %%
def update_candidates(used_candidates = None, candidates = None, vertex_to_clique = None):
    """
    если клика пустая выдает ошибку - нужно использовать find_candidates
    если клика не пустая то обновляет множетсво кандидитов:
        в него включаются те вершины, которые есть в кандидатах
        и те вершины, которые есть в соседях у вершины vertex_to_clique, которая
        в данный момент добавляется в клику
    """
    global clique #, candidates
    
    if len(clique) == 0:
        raise NameError('len(clique) == 0. Use find_candidates')
    if candidates is None:
        raise NameError('candidates = None')
    if used_candidates is None:
        used_candidates = set()
    else:
        if vertex_to_clique not in candidates:
            raise NameError(vertex_to_clique,'No such vertex in candidates')
        updated_candidates = candidates.intersection(g.V[vertex_to_clique]['neighbours']) - used_candidates
    return updated_candidates

# %%
def initial_heuristic_degree():
    clique = set()
    g.sort_vertex_by_degree()
#     print(type(clique))
    for vertex in g.D:
#         print(type(clique),type(vertex))
        
        all_elements_in_clique_are_neighbours_to_vertex = True
        for element in clique:
            all_elements_in_clique_are_neighbours_to_vertex = all_elements_in_clique_are_neighbours_to_vertex and g.is_neighbour(vertex['name'],element)
            if not all_elements_in_clique_are_neighbours_to_vertex:
                break
#         print(vertex['name'],all_elements_in_clique_are_neighbours_to_vertex )
        if all_elements_in_clique_are_neighbours_to_vertex:
            clique.add(vertex['name'])
    return clique

# %%
def initial_heuristic_color(rev = False):
    """
    makes clique:
    first - vericies with maximal color
    """
    clique = set()
    g.sort_vertex_by_degree()
    if rev:
        color_range =  range(len(g.used_colors)-1,-1,-1)
    else:
        color_range =  range(len(g.used_colors))
    for color in color_range:
        for vertex_name in g.used_colors[color]:
            all_elements_in_clique_are_neighbours_to_vertex = True
            for element_name in clique:
                all_elements_in_clique_are_neighbours_to_vertex = all_elements_in_clique_are_neighbours_to_vertex and g.is_neighbour(vertex_name,element_name)
                if not all_elements_in_clique_are_neighbours_to_vertex:
                    break
#             print(vertex_name,all_elements_in_clique_are_neighbours_to_vertex )
            if all_elements_in_clique_are_neighbours_to_vertex:
                clique.add(vertex_name)
    return clique

# %%
def find_best_heuristic():
    init_clique = initial_heuristic_color()
    init_clique_rev = initial_heuristic_color(True)
    init_clique_degree = initial_heuristic_degree()
    len_best_heuristic =  max( len(init_clique),len(init_clique_rev),len(init_clique_degree)  )
    return max(init_clique,init_clique_rev,init_clique_degree),len_best_heuristic

# %%
def find_best_heuristic_new():
    g.clear_coloring()
    g.recolor()
    init_clique_1 = initial_heuristic_color()
    init_clique_rev_1 = initial_heuristic_color(True)
    init_clique_degree_1 = initial_heuristic_degree()
    len_best_heuristic_1 =  max( len(init_clique_1),len(init_clique_rev_1),len(init_clique_degree_1)  )
    best_heuristic_1 = max(init_clique_1,init_clique_rev_1,init_clique_degree_1)
    
    g.clear_coloring()
    g.recolor_by_degree()
    init_clique_2 = initial_heuristic_color()
    init_clique_rev_2 = initial_heuristic_color(True)
    init_clique_degree_2 = initial_heuristic_degree()
    len_best_heuristic_2 =  max( len(init_clique_2),len(init_clique_rev_2),len(init_clique_degree_2)  )
    best_heuristic_2 = max(init_clique_2,init_clique_rev_2,init_clique_degree_2)
    
    g.clear_coloring()
    g.recolor_by_degree(rev = True)
    init_clique_3 = initial_heuristic_color()
    init_clique_rev_3 = initial_heuristic_color(True)
    init_clique_degree_3 = initial_heuristic_degree()
    len_best_heuristic_3 =  max( len(init_clique_3),len(init_clique_rev_3),len(init_clique_degree_3)  )
    best_heuristic_3 = max(init_clique_3,init_clique_rev_3,init_clique_degree_3)
    
    
    len_best_heuristic =  max(len_best_heuristic_1, len_best_heuristic_2, len_best_heuristic_3)
    return max(best_heuristic_1,best_heuristic_2,best_heuristic_3),len_best_heuristic

# %%
path_e_1_1 = 'test/brock200_1.clq.txt'
path_e_1_2 = 'test/brock200_2.clq.txt'
path_e_1_3 = 'test/brock200_3.clq.txt'
path_e_1_4 = 'test/brock200_4.clq.txt'
path_e_2_1 = 'test/gen200_p0.9_44.clq.txt'
path_e_2_2 = 'test/gen200_p0.9_55.clq.txt'
path_e_3 = 'test/hamming8-4.clq.txt'
path_e_4 = 'test/johnson16-2-4.clq.txt'
path_e_5 = 'test/keller4.clq.txt'
path_e_6 = 'test/MANN_a27.clq.txt'
path_e_7 = 'test/p_hat1000-1.clq.txt'

# %% [markdown]
# # Графовые функции branch_and_cut

# %%
def find_normed_degree_dict(g):
    """
    for veretx with the lowes degree - 1
    for veretx with the highest degree - 0
    
    made to find vertexes with lowest degree
    for use in find_most_violated_greedy_and_degree
    
    """
    degree_arr = []
    for vertex_name in g.V:
        (vertex_name - 1, g.V[vertex_name]['degree'])
        degree_arr.append( (vertex_name -1 , g.V[vertex_name]['degree'])  ) # degree_arr - array of tupples (vertex_index,vertex_deg)
    degree_arr.sort(key = lambda i: i[1], reverse = False)
    
    min_degree = degree_arr[0][1]
    max_degree = degree_arr[-1][1]
    
    normed_degree_dict = dict()
    for index in range(len(degree_arr)):
        vertex_index = degree_arr[index][0]
        degree = degree_arr[index][1]
        normed_degree = 1 - (degree-min_degree)/(max_degree-min_degree)

        normed_degree_dict[vertex_index] = normed_degree
    return normed_degree_dict

# %%
def find_independent_sets_by_coloring(coloring_colors, vertex_coloring, candidates):
    global g
    colors = copy.deepcopy(coloring_colors)
    ind_sets_coloring = dict()
    for vertex_name in vertex_coloring:
        ind_sets_coloring[vertex_name] = {vertex_coloring[vertex_name]}
    for color in colors:
        for vertex_name in coloring_colors[color]:
            available_colors = set(colors.keys())
            available_neighbours = g.V[vertex_name]['neighbours'].intersection(candidates)
            while len(available_neighbours) > 0:
                neighbour = available_neighbours.pop()
                neighbour_color = vertex_coloring[neighbour]
                neighbour_colors_set = ind_sets_coloring[neighbour]
                available_colors -= {neighbour_color}.union(neighbour_colors_set)
                for n_color in neighbour_colors_set:
                    available_neighbours -= colors[n_color]
            check_neighbours = set()
            # есть цвета по которым может быть пересечение. Их надо проверить
            for available_color in available_colors:
                available_neighbours = g.V[vertex_name]['neighbours'].intersection(candidates)
                available_neighbours = available_neighbours.intersection(
                    colors[available_color])  # change to colors
                check_neighbours = check_neighbours.union(available_neighbours)
            for neighbour in check_neighbours:
                available_colors -= ind_sets_coloring[neighbour]
            for available_color in available_colors:
                colors[available_color].add(vertex_name)
            ind_sets_coloring[vertex_name] = ind_sets_coloring[vertex_name].union(available_colors)
    return colors, ind_sets_coloring

# %% [markdown]
# # CPLEX функции branch_and_cut

# %%
def ind_sets_most_violated(ind_set: set):
    """
    set is set of indexes
    """

    for vertex_index_1 in ind_set:
        for vertex_index_2 in ind_set:
            if vertex_index_1 is not vertex_index_2:
                vertex_name_1 = vertex_index_1 + 1
                vertex_name_2 = vertex_index_2 + 1
                if  g.is_neighbour(vertex_name_1,vertex_name_2):
                    print(g.is_neighbour(vertex_name_1,vertex_name_2))
    print('if pusto - OK')

# %%
def find_most_violated_greedy_and_degree_maybe_new(random_range = 4, sum_without_random = 5, expandable_set = None):
    """
    Heuristical algorithm to find_most_violated_greedy_and_degree
    
    random_range - number of iterations with randomes(alpha,betta)
    sum_without_random - if summ if vertex variable more than sum_without_random,
    algorithm don`t use random iterations
    
    best_ind_set - set of vertex_indexes 
    best_sum - sum of variables for best_ind_set
    """
    global x,mdl, normed_degree_dict, x_vars
    alpha_arr = [1]
    betta_arr = [0]
    best_sum = 0
    if expandable_set is not None:
             best_sum = -1
    best_ind_set = {}
    
    for i in range(random_range):
        alpha_arr.append(random.uniform(0,1))
        betta_arr.append(random.uniform(0,1))
    for alpha, betta in zip(alpha_arr,betta_arr):
        sum_x = 0
        # x_vars - array of tupples (vertex_index,vertex_variable)
        # sol.iter_var_values() - iteration by nonzero variable_values
        x_vars = [(vertex_variable.get_index(),vertex_variable) for (vertex_variable,vertex_variable_val) in sol.iter_var_values()]
        x_vars.sort(key = lambda i: alpha * i[1].solution_value + betta * normed_degree_dict[i[0]], reverse = True)#sort partly by degree and by solution valuae
        if expandable_set is None:
            ind_set = set()
            ind_set.add (x_vars[0][0])
        else:
            ind_set = expandable_set
        for vertex_index_1,vertex_variable in x_vars: # index = vertex_name - 1
            addition_forbidden = False
            for vertex_index_2 in ind_set:
                vertex_name_1 = vertex_index_1 + 1
                vertex_name_2 = vertex_index_2 + 1
                if g.is_neighbour(vertex_name_1,vertex_name_2):
                    addition_forbidden = True
                    break
            if not addition_forbidden:
                ind_set.add (vertex_index_1)
                sum_x += vertex_variable.solution_value
        if sum_x > best_sum:
            best_sum = sum_x
            best_ind_set = ind_set
        if sum_x > sum_without_random:
            break
    return best_ind_set, best_sum

# %%
def find_most_violated_greedy_and_degree(random_range = 4, sum_without_random = 5):
    """
    Heuristical algorithm to find_most_violated_greedy_and_degree
    
    random_range - number of iterations with randomes(alpha,betta)
    sum_without_random - if summ if vertex variable more than sum_without_random,
    algorithm don`t use random iterations
    
    best_ind_set - set of vertex_indexes 
    best_sum - sum of variables for best_ind_set
    """
    global x,mdl, normed_degree_dict, x_vars
    alpha_arr = [1]
    betta_arr = [0]
    best_sum = 0
    best_ind_set = {}
    
    for i in range(random_range):
        alpha_arr.append(random.uniform(0,1))
        betta_arr.append(random.uniform(0,1))
    for alpha, betta in zip(alpha_arr,betta_arr):
        sum_x = 0
        # x_vars - array of tupples (vertex_index,vertex_variable)
        # sol.iter_var_values() - iteration by nonzero variable_values
        x_vars = [(vertex_variable.get_index(),vertex_variable) for (vertex_variable,vertex_variable_val) in sol.iter_var_values()]
        x_vars.sort(key = lambda i: alpha * i[1].solution_value + betta * normed_degree_dict[i[0]], reverse = True)#sort partly by degree and by solution valuae
        ind_set = set()
        ind_set.add (x_vars[0][0])
        for vertex_index_1,vertex_variable in x_vars: # index = vertex_name - 1
            addition_forbidden = False
            for vertex_index_2 in ind_set:
                vertex_name_1 = vertex_index_1 + 1
                vertex_name_2 = vertex_index_2 + 1
                if g.is_neighbour(vertex_name_1,vertex_name_2):
                    addition_forbidden = True
                    break
            if not addition_forbidden:
                ind_set.add (vertex_index_1)
                sum_x += vertex_variable.solution_value
        if sum_x > best_sum:
            best_sum = sum_x
            best_ind_set = ind_set
        if sum_x > sum_without_random:
            break
    return best_ind_set, best_sum

# %%
def build_problem():
    """
    makes new global mdl - model, x - variables of model
    by existing global graph g 
    """
    
    global mdl,x,g
    mdl = Model(name='max clique')
    x_range = range(len(g.V))
    # decision variables
    # x = mdl.integer_var_dict(x_range)
    x = mdl.continuous_var_dict(x_range)
    ind_sets_arr = []
    clique = set() # for find_candidates()
    candidates = find_candidates()
    (colors, vertex_coloring) = candidates_recolor(candidates)
    ind_sets_arr.append(find_independent_sets_by_coloring(colors, vertex_coloring, candidates)[0])
    (colors, vertex_coloring) = candidates_recolor_degree(candidates)
    ind_sets_arr.append(find_independent_sets_by_coloring(colors, vertex_coloring, candidates)[0])
    (colors, vertex_coloring) = candidates_recolor_degree(candidates, rev=True)
    ind_sets_arr.append(find_independent_sets_by_coloring(colors, vertex_coloring, candidates)[0])

    for ind_sets in ind_sets_arr:
        for ind_set in ind_sets:
            # print(i, colors2[i])
    #         if len(ind_sets[ind_set]) > 1:
            mdl.add_constraint(mdl.sum(x[vertex_name-1] for vertex_name in ind_sets[ind_set]) <= 1) #vertex_index = vertex_name-1

#     for i in range(mdl.number_of_constraints):
#         print(mdl.get_constraint_by_index(i))

    for i in x_range:
#         mdl.add_constraint(x[i] <= 1)
        mdl.add_constraint(x[i] >= 0)

    mdl.maximize(mdl.sum(x[i] for i in x_range))

# %%
def is_int_value(value):
    """
    True - if int
    False if float
    
    """
    
    if value % 1 > eps and abs(value % 1 - 1) > eps:
        return False
    return True

# %%
def is_int_solution():
    """
    True - if all variables int
    False if even one of variables is float
    """
    global sol
    
    sol_val = sol.get_objective_value()
    if not is_int_value(sol_val):
        return False
    for var in sol.iter_var_values():
        if not is_int_value(var[1]):
            return False
    return True

# %%
def is_a_clique():
    """
    check solution if is_int_solution() is True
    
    function check if varticies vith x = 1 are clique or not
    """
    global sol, x_vars,g
    
    vertex_names = [i[0].index+1 for i in sol.iter_var_values()] #заменить на x_vars уточнить 
    for vertex_name_1 in vertex_names:
        for vertex_name_2 in vertex_names:
            if vertex_name_1 is not vertex_name_2:
                if not g.is_neighbour(vertex_name_1,vertex_name_2):
                    print(f"{vertex_name_1,vertex_name_2} are not neighbours. Not a clique")
                    return False
    return True

# %%
def add_non_edges_constraints_maybe_new():
    """
    work if  is_a_clique() is False
    function add new constraints for if varticies vith x = 1 if they are not neighbours
    """
    global sol, x_vars,g
#     non_edges = []
    vertex_indexes = [i[0].index for i in sol.iter_var_values()]
    for vertex_index_1 in vertex_indexes:
        for vertex_index_2 in vertex_indexes:
            if vertex_index_1 is not vertex_index_2:
                vertex_name_1 = vertex_index_1 + 1
                vertex_name_2 = vertex_index_2 + 1
                if not g.is_neighbour(vertex_name_1,vertex_name_2):
                    ind_set = {vertex_name_1,vertex_name_2}
                    
                    con = x[vertex_index_1] + x[vertex_index_2] <= 1
                    mdl.add_constraint(con)
                    
                    print(f"{vertex_name_1,vertex_name_2} are not neighbours. Added {con}")

# %%
def add_non_edges_constraints():
    """
    work if  is_a_clique() is False
    function add new constraints for if varticies vith x = 1 if they are not neighbours
    """
    global sol, x_vars,g
#     non_edges = []
    vertex_names = [i[0].index+1 for i in sol.iter_var_values()]
    for vertex_name_1 in vertex_names:
        for vertex_name_2 in vertex_names:
            if vertex_name_1 is not vertex_name_2:
                if not g.is_neighbour(vertex_name_1,vertex_name_2):
                    vertex_index_1 = vertex_name_1 - 1
                    vertex_index_2 = vertex_name_2 - 1
                    con = x[vertex_index_1] + x[vertex_index_2] <= 1
                    mdl.add_constraint(con)
                    
                    print(f"{vertex_name_1,vertex_name_2} are not neighbours. Added {con}")

# %% [raw]
# mdl.add_constraint(mdl.sum(x[vertex_name-1] for vertex_name in ind_sets[ind_set]) <= 1)

# %%
def get_non_edges_old(sol, g=Graph()):
    non_edges = []
    var_values = [i[0] for i in sol.iter_var_values()]
    for i in range(len(var_values)):
        for j in range(i+1, len(var_values)):
            if var_values[j].index+1 not in g.V[var_values[i].index+1]['neighbours']:
                non_edges.append((var_values[j], var_values[i]))
    return non_edges

# %%
def branch_and_cut_choose_branching_var():
    """
    x_vars - sort partly by degree and by solution valuae f
    x_vars from find_most_violated_greedy_and_degree
    algorithm choose first available float variable from sorted x_vars 
    return fraction_variable_index
    """
    global len_max_current_clique, sol, x_vars

    ind_set, x_sum = find_most_violated_greedy_and_degree(sum_without_random = 0)    # to sort x_vars by var_value
    if len(ind_set) > 2:
        mdl.add_constraint(mdl.sum(x[i] for i in ind_set) <= 1)    # to sort x_vars by var_value
        sol = mdl.solve()    # to sort x_vars by var_value
    
    for vertex_index, vertex_var in x_vars:
        if not is_int_value(vertex_var.solution_value):
            fraction_variable_index = vertex_index
            break
    return fraction_variable_index

# %%
def branch_and_cut_search(sum_without_random = 2):
    global len_max_current_clique, sol, x_vars
    sol = mdl.solve() # нужно ли тут
    if sol is None:
        return
    
    if sol.get_objective_value() <= len_max_current_clique:
        return
    
    
    first_time = True # to do first iteration on while every time
    
    while first_time or x_sum > 1 :
        ind_set, x_sum = find_most_violated_greedy_and_degree(sum_without_random)
        if len(ind_set) <= 1:
            break
        most_violated_con = mdl.sum(x[i] for i in ind_set) <= 1
        mdl.add_constraint(most_violated_con)
        print(f'{most_violated_con} added')
        sol = mdl.solve()
        
        if sol is None:
            print(f'{most_violated_con} makes no solution')
            return
        print(f'x_sum = {x_sum},len(ind_set) = {len(ind_set)} number_of_constraints  = {mdl.number_of_constraints}, obj = {sol.get_objective_value()}')
        if  is_int_solution():
            break
        first_time = False
        
    if not is_int_solution():
        fraction_variable_index = branch_and_cut_choose_branching_var()
        con1 = x[fraction_variable_index] >= 1
        con2 = x[fraction_variable_index] <= 0
        mdl.add_constraint(con1)
        branch_and_cut_search()
        mdl.remove_constraint(con1)
        
        mdl.add_constraint(con2)
        branch_and_cut_search()
        mdl.remove_constraint(con2)
    else: # solution is int 
        print('solution_int')
        if is_a_clique():
            len_max_current_clique = sol.get_objective_value()
            print(f"current_clique is {len_max_current_clique}")
            
        else:
            add_non_edges_constraints()
#     print(con1,con2)

# %% [markdown]
# # Algorithm

# %%
path_e_1_1 = 'test/brock200_1.clq.txt'
path_e_1_2 = 'test/brock200_2.clq.txt'
path_e_1_3 = 'test/brock200_3.clq.txt'
path_e_1_4 = 'test/brock200_4.clq.txt'
path_e_2_1 = 'test/gen200_p0.9_44.clq.txt'
path_e_2_2 = 'test/gen200_p0.9_55.clq.txt'
path_e_3 = 'test/hamming8-4.clq.txt'
path_e_4 = 'test/johnson16-2-4.clq.txt'
path_e_5 = 'test/keller4.clq.txt'
path_e_6 = 'test/MANN_a27.clq.txt'
path_e_7 = 'test/p_hat1000-1.clq.txt'

# %%
g = read_dimacs_graph(path_e_1_1);
# Out:
# FILE: brock200_1.b
#
# Graph Generator
#
# By: Mark Brockington (brock@cs.ualberta.ca)
# and Joe Culberson (joe@cs.ualberta.ca)
#
# Graph Size:200, Clique Size: 21
# Seed:0, Edge Density: 0.75000
# Depth 1 Hiding
#
# Clique Elements are:
# 133 17 92 177 38 19 84 134 107 89
# 185 91 67 141 149 72 101 135 86 93
# 80
#
# Estimated Size of Uncompressed File: 0.1MB
#
# edge 200 14834

# %%
normed_degree_dict = find_normed_degree_dict(g)

# %%
_,len_max_current_clique = find_best_heuristic_new()
print(len_max_current_clique)
# Out:
# 18

# %%
clique = set() # for build_problem()
x_vars = 0
sol = 0

# %%
build_problem()

# %%
len(x)
# Out:
# 200

# %%
sol = mdl.solve()

# %%
branch_and_cut_search(sum_without_random = 2)
# Out:
# x48+x141+x174+x195 <= 1 added
# x_sum = 2.8853999420945966,len(ind_set) = 4 number_of_constraints  = 376, obj = 50.37869249394673
# x21+x65+x143+x161 <= 1 added
# x_sum = 2.5396287328490725,len(ind_set) = 4 number_of_constraints  = 377, obj = 49.99992234819072
# x49+x75+x127+x142 <= 1 added
# x_sum = 2.7147654915359527,len(ind_set) = 4 number_of_constraints  = 378, obj = 49.34094654084226
# x21+x62+x92+x187+x189 <= 1 added
# x_sum = 3.172162870450316,len(ind_set) = 5 number_of_constraints  = 379, obj = 48.9058762726546
# x9+x62+x71+x191 <= 1 added
# x_sum = 2.243316347424671,len(ind_set) = 4 number_of_constraints  = 380, obj = 48.62074888467935
# x35+x94+x128+x168 <= 1 added
# x_sum = 2.6263814087087898,len(ind_set) = 4 number_of_constraints  = 381, obj = 48.50204406105575
# x53+x103+x117+x161 <= 1 added
# x_sum = 2.5908540984111776,len(ind_set) = 4 number_of_constraints  = 382, obj = 48.34262522856377
# x39+x58+x152 <= 1 added
# x_sum = 2.1456948547555634,len(ind_set) = 3 number_of_constraints  = 383, obj = 48.230916004160235
# x101+x165+x182+x191 <= 1 added
# x_sum = 2.250721118382017,len(ind_set) = 4 number_of_constraints  = 384, obj = 48.0340566571122
# x128+x132+x153+x155 <= 1 added
# x_sum = 1.96314370532458,len(ind_set) = 4 number_of_constraints  = 385, obj = 47.955069765896106
# x97+x156+x167+x199 <= 1 added
# x_sum = 1.8867314280057235,len(ind_set) = 4 number_of_constraints  = 386, obj = 47.860686646601145
# x17+x47+x80+x131 <= 1 added
# x_sum = 2.371162905207752,len(ind_set) = 4 number_of_constraints  = 387, obj = 47.735803010637845
# x49+x60+x68+x89+x200 <= 1 added
# x_sum = 1.8312340447311373,len(ind_set) = 5 number_of_constraints  = 388, obj = 47.63819968292088
# x48+x61+x85+x118+x133 <= 1 added
# x_sum = 2.6533454324200925,len(ind_set) = 5 number_of_constraints  = 389, obj = 47.38370759164377
# x52+x147+x186 <= 1 added
# x_sum = 2.3481459604184467,len(ind_set) = 3 number_of_constraints  = 390, obj = 47.27897820112945
# x8+x173+x177 <= 1 added
# x_sum = 1.8037914195098672,len(ind_set) = 3 number_of_constraints  = 391, obj = 47.22176270130071
# x41+x106+x141+x170 <= 1 added
# x_sum = 2.0374784725830843,len(ind_set) = 4 number_of_constraints  = 392, obj = 47.143494150137506
# x24+x61+x118+x123 <= 1 added
# x_sum = 1.8880927550667828,len(ind_set) = 4 number_of_constraints  = 393, obj = 47.05290667028661
# x14+x86+x102+x137+x146 <= 1 added
# x_sum = 1.8296799423822163,len(ind_set) = 5 number_of_constraints  = 394, obj = 47.017211876121245
# x51+x91+x137+x190+x196 <= 1 added
# x_sum = 2.1090213165936653,len(ind_set) = 5 number_of_constraints  = 395, obj = 46.93592536192216
# x39+x115+x152+x158 <= 1 added
# x_sum = 1.973636381113351,len(ind_set) = 4 number_of_constraints  = 396, obj = 46.841044514281336
# x89+x144+x193 <= 1 added
# x_sum = 1.7734416076239021,len(ind_set) = 3 number_of_constraints  = 397, obj = 46.799125921873234
# x60+x71+x90+x164 <= 1 added
# x_sum = 2.1240065132896224,len(ind_set) = 4 number_of_constraints  = 398, obj = 46.76273405323643
# x63+x79+x107+x168 <= 1 added
# x_sum = 2.4227092679623583,len(ind_set) = 4 number_of_constraints  = 399, obj = 46.723615942654305
# x16+x67+x172 <= 1 added
# x_sum = 2.233222152081788,len(ind_set) = 3 number_of_constraints  = 400, obj = 46.662011350470294
# x43+x153+x167+x169+x178 <= 1 added
# x_sum = 2.252705893243802,len(ind_set) = 5 number_of_constraints  = 401, obj = 46.50625079270374
# x23+x69+x132+x183 <= 1 added
# x_sum = 2.1381668700382437,len(ind_set) = 4 number_of_constraints  = 402, obj = 46.426950088862554
# x52+x82+x130+x157 <= 1 added
# x_sum = 2.2635501635083335,len(ind_set) = 4 number_of_constraints  = 403, obj = 46.36459940516771
# x27+x57+x102 <= 1 added
# x_sum = 1.9365250820864015,len(ind_set) = 3 number_of_constraints  = 404, obj = 46.34191388091276
# x49+x56+x134+x165+x166 <= 1 added
# x_sum = 1.7773539704512413,len(ind_set) = 5 number_of_constraints  = 405, obj = 46.31709319393233
# x38+x118+x120+x150 <= 1 added
# x_sum = 2.1884339224850655,len(ind_set) = 4 number_of_constraints  = 406, obj = 46.26814968735459
# x9+x55+x83+x181 <= 1 added
# x_sum = 2.1005418392186894,len(ind_set) = 4 number_of_constraints  = 407, obj = 46.19605297748731
# x78+x121+x147+x176 <= 1 added
# x_sum = 1.7694219382952192,len(ind_set) = 4 number_of_constraints  = 408, obj = 46.15765841126369
# x13+x35+x89+x115 <= 1 added
# x_sum = 2.1196565517589434,len(ind_set) = 4 number_of_constraints  = 409, obj = 46.041796185929854
# x38+x47+x76+x118 <= 1 added
# x_sum = 2.2076237713154296,len(ind_set) = 4 number_of_constraints  = 410, obj = 45.974118795163236
# x1+x12+x177+x193 <= 1 added
# x_sum = 1.5651740893283768,len(ind_set) = 4 number_of_constraints  = 411, obj = 45.95362847561187
# x88+x127+x138+x143 <= 1 added
# x_sum = 2.2240379314362277,len(ind_set) = 4 number_of_constraints  = 412, obj = 45.90722104672816
# x8+x31+x166+x191 <= 1 added
# x_sum = 2.237680016979396,len(ind_set) = 4 number_of_constraints  = 413, obj = 45.86161543209693
# x24+x49+x60+x63+x123 <= 1 added
# x_sum = 1.742745662381862,len(ind_set) = 5 number_of_constraints  = 414, obj = 45.80488636959529
# x59+x155+x160 <= 1 added
# x_sum = 1.638539025254257,len(ind_set) = 3 number_of_constraints  = 415, obj = 45.763447604157214
# x3+x21+x30+x100 <= 1 added
# x_sum = 1.8635425741919893,len(ind_set) = 4 number_of_constraints  = 416, obj = 45.6950587813481
# x19+x55+x75+x94 <= 1 added
# x_sum = 1.9224717570066607,len(ind_set) = 4 number_of_constraints  = 417, obj = 45.66474233111002
# x21+x75+x83+x177 <= 1 added
# x_sum = 1.7288700745003125,len(ind_set) = 4 number_of_constraints  = 418, obj = 45.62613582406943
# x54+x144+x165+x183 <= 1 added
# x_sum = 1.8657143290438691,len(ind_set) = 4 number_of_constraints  = 419, obj = 45.56434142705663
# x29+x69+x172+x182 <= 1 added
# x_sum = 2.0502052846290475,len(ind_set) = 4 number_of_constraints  = 420, obj = 45.47667136157952
# x34+x103+x161 <= 1 added
# x_sum = 1.579543553081546,len(ind_set) = 3 number_of_constraints  = 421, obj = 45.41584837764583
# x4+x98+x154 <= 1 added
# x_sum = 1.7863605484997707,len(ind_set) = 3 number_of_constraints  = 422, obj = 45.39153445915964
# x32+x66+x106+x149 <= 1 added
# x_sum = 1.9432153155287126,len(ind_set) = 4 number_of_constraints  = 423, obj = 45.36093681377343
# x38+x114+x168+x183 <= 1 added
# x_sum = 1.6278241132584061,len(ind_set) = 4 number_of_constraints  = 424, obj = 45.3281394984529
# x9+x50+x59+x90+x191 <= 1 added
# x_sum = 2.3187549402336542,len(ind_set) = 5 number_of_constraints  = 425, obj = 45.21171168353114
# x31+x79+x182+x186 <= 1 added
# x_sum = 2.127720373282587,len(ind_set) = 4 number_of_constraints  = 426, obj = 45.134524290309756
# x27+x64+x102+x167 <= 1 added
# x_sum = 1.7579590180212603,len(ind_set) = 4 number_of_constraints  = 427, obj = 45.11057358379636
# x14+x150+x161+x164 <= 1 added
# x_sum = 1.664586359940421,len(ind_set) = 4 number_of_constraints  = 428, obj = 45.08913113450309
# x81+x109+x172+x196 <= 1 added
# x_sum = 1.8917537098970865,len(ind_set) = 4 number_of_constraints  = 429, obj = 45.04921231520531
# x118+x124+x139+x173+x180 <= 1 added
# x_sum = 1.937524479443839,len(ind_set) = 5 number_of_constraints  = 430, obj = 45.01102566990385
# x39+x66+x107+x116 <= 1 added
# x_sum = 1.76456578535958,len(ind_set) = 4 number_of_constraints  = 431, obj = 45.001788603299644
# x27+x65+x78+x158+x167 <= 1 added
# x_sum = 1.8965673426138396,len(ind_set) = 5 number_of_constraints  = 432, obj = 44.96073981382723
# x84+x156+x175+x198 <= 1 added
# x_sum = 1.6192925136717846,len(ind_set) = 4 number_of_constraints  = 433, obj = 44.93819283752913
# x19+x28+x102+x123 <= 1 added
# x_sum = 1.9228654741403532,len(ind_set) = 4 number_of_constraints  = 434, obj = 44.91347122539521
# x10+x163+x185+x198 <= 1 added
# x_sum = 1.7510599525539081,len(ind_set) = 4 number_of_constraints  = 435, obj = 44.89892857604779
# x4+x30+x57+x140 <= 1 added
# x_sum = 1.5266272193750834,len(ind_set) = 4 number_of_constraints  = 436, obj = 44.87557139544703
# x16+x41+x148+x160 <= 1 added
# x_sum = 1.6306549733554259,len(ind_set) = 4 number_of_constraints  = 437, obj = 44.86479755751536
# x71+x77+x164+x173 <= 1 added
# x_sum = 1.55885776157089,len(ind_set) = 4 number_of_constraints  = 438, obj = 44.84748879275078
# x17+x34+x186+x197 <= 1 added
# x_sum = 1.4756338570363283,len(ind_set) = 4 number_of_constraints  = 439, obj = 44.840111621842205
# x12+x49+x89+x124 <= 1 added
# x_sum = 1.3324047796303837,len(ind_set) = 4 number_of_constraints  = 440, obj = 44.83824550562377
# x119+x144+x154+x192 <= 1 added
# x_sum = 1.7038306975592283,len(ind_set) = 4 number_of_constraints  = 441, obj = 44.79838570050906
# x18+x86+x103+x143 <= 1 added
# x_sum = 1.7756312710619173,len(ind_set) = 4 number_of_constraints  = 442, obj = 44.74384399483371
# x77+x94+x115+x121 <= 1 added
# x_sum = 1.943366917147746,len(ind_set) = 4 number_of_constraints  = 443, obj = 44.719902309485086
# x71+x84+x92+x116 <= 1 added
# x_sum = 1.7449421895019022,len(ind_set) = 4 number_of_constraints  = 444, obj = 44.69395123641095
# x2+x8+x80+x106+x187 <= 1 added
# x_sum = 2.107153445833092,len(ind_set) = 5 number_of_constraints  = 445, obj = 44.653651913912974
# x31+x42+x69+x141+x196 <= 1 added
# x_sum = 1.8712257336509004,len(ind_set) = 5 number_of_constraints  = 446, obj = 44.591906284299405
# x3+x16+x47+x148+x186 <= 1 added
# x_sum = 2.0148016337763215,len(ind_set) = 5 number_of_constraints  = 447, obj = 44.49846613992095
# x6+x103+x181 <= 1 added
# x_sum = 1.4468234617464173,len(ind_set) = 3 number_of_constraints  = 448, obj = 44.47290444171483
# x103+x129+x150+x161 <= 1 added
# x_sum = 1.3960201206823541,len(ind_set) = 4 number_of_constraints  = 449, obj = 44.45368722494134
# x127+x132+x166 <= 1 added
# x_sum = 1.6432512542870614,len(ind_set) = 3 number_of_constraints  = 450, obj = 44.41893303123759
# x77+x81+x112+x147+x173 <= 1 added
# x_sum = 1.6191394497637677,len(ind_set) = 5 number_of_constraints  = 451, obj = 44.38200046029744
# x74+x139+x162+x176 <= 1 added
# x_sum = 1.6159901556425522,len(ind_set) = 4 number_of_constraints  = 452, obj = 44.35145906630603
# x64+x98+x111+x190 <= 1 added
# x_sum = 1.7916733870468022,len(ind_set) = 4 number_of_constraints  = 453, obj = 44.33447416337487
# x55+x135+x151+x171 <= 1 added
# x_sum = 1.9264089453650564,len(ind_set) = 4 number_of_constraints  = 454, obj = 44.31932991792639
# x30+x68+x82+x126 <= 1 added
# x_sum = 1.7173977156359412,len(ind_set) = 4 number_of_constraints  = 455, obj = 44.31032026301791
# x84+x122+x174+x198 <= 1 added
# x_sum = 1.5155922342825625,len(ind_set) = 4 number_of_constraints  = 456, obj = 44.306259405643516
# x1+x57+x101+x177 <= 1 added
# x_sum = 1.5523055080551411,len(ind_set) = 4 number_of_constraints  = 457, obj = 44.29204303375909
# x6+x57+x79+x195 <= 1 added
# x_sum = 1.427353317727608,len(ind_set) = 4 number_of_constraints  = 458, obj = 44.28166580231867
# x97+x121+x174+x189 <= 1 added
# x_sum = 1.538809590200728,len(ind_set) = 4 number_of_constraints  = 459, obj = 44.270928820949486
# x4+x11+x17+x177 <= 1 added
# x_sum = 1.6450814557725777,len(ind_set) = 4 number_of_constraints  = 460, obj = 44.26093668227608
# x5+x149+x156+x173 <= 1 added
# x_sum = 1.687991156518764,len(ind_set) = 4 number_of_constraints  = 461, obj = 44.24962022210973
# x43+x114+x130+x146+x172 <= 1 added
# x_sum = 1.5397685966145431,len(ind_set) = 5 number_of_constraints  = 462, obj = 44.23959049769232
# x46+x155+x156+x179 <= 1 added
# x_sum = 1.648651097058074,len(ind_set) = 4 number_of_constraints  = 463, obj = 44.2272499007479
# x62+x84+x123+x151 <= 1 added
# x_sum = 1.6680992151438032,len(ind_set) = 4 number_of_constraints  = 464, obj = 44.204736298961876
# x5+x30+x129+x134+x146+x176 <= 1 added
# x_sum = 1.465094878067689,len(ind_set) = 6 number_of_constraints  = 465, obj = 44.19541853469332
# x22+x24+x73+x119 <= 1 added
# x_sum = 1.4201158905736224,len(ind_set) = 4 number_of_constraints  = 466, obj = 44.187757994482766
# x48+x49+x68+x172 <= 1 added
# x_sum = 1.503525010445314,len(ind_set) = 4 number_of_constraints  = 467, obj = 44.169476877820316
# x32+x91+x143+x154 <= 1 added
# x_sum = 1.4108734691419595,len(ind_set) = 4 number_of_constraints  = 468, obj = 44.152008597863365
# x82+x92+x99+x122+x154 <= 1 added
# x_sum = 1.738808460593711,len(ind_set) = 5 number_of_constraints  = 469, obj = 44.13746996847569
# x54+x141+x159+x162 <= 1 added
# x_sum = 1.5320892247677504,len(ind_set) = 4 number_of_constraints  = 470, obj = 44.12218696280624
# x29+x69+x93+x144 <= 1 added
# x_sum = 1.5267861167679335,len(ind_set) = 4 number_of_constraints  = 471, obj = 44.098436061497
# x58+x112+x152+x160 <= 1 added
# x_sum = 1.806563958799176,len(ind_set) = 4 number_of_constraints  = 472, obj = 44.06701625128364
# x10+x87+x109+x185 <= 1 added
# x_sum = 1.5739671439054617,len(ind_set) = 4 number_of_constraints  = 473, obj = 44.05845970320702
# x18+x53+x86+x133+x169 <= 1 added
# x_sum = 1.578563192720201,len(ind_set) = 5 number_of_constraints  = 474, obj = 44.04726249224837
# x66+x101+x111+x166 <= 1 added
# x_sum = 1.6147183597259622,len(ind_set) = 4 number_of_constraints  = 475, obj = 44.04063567547496
# x24+x96+x135+x176+x197 <= 1 added
# x_sum = 1.6681378256532433,len(ind_set) = 5 number_of_constraints  = 476, obj = 44.006946935658064
# x52+x68+x131+x155+x163 <= 1 added
# x_sum = 1.8110222828454443,len(ind_set) = 5 number_of_constraints  = 477, obj = 43.97578981976314
# x6+x37+x39+x176 <= 1 added
# x_sum = 1.3310136224290796,len(ind_set) = 4 number_of_constraints  = 478, obj = 43.964539019355364
# x42+x47+x66+x86+x113 <= 1 added
# x_sum = 1.5922145396355112,len(ind_set) = 5 number_of_constraints  = 479, obj = 43.94623630116911
# x47+x86+x124+x127+x169 <= 1 added
# x_sum = 1.3064465854261726,len(ind_set) = 5 number_of_constraints  = 480, obj = 43.936161485936864
# x44+x60+x71+x73+x138 <= 1 added
# x_sum = 1.630154140054083,len(ind_set) = 5 number_of_constraints  = 481, obj = 43.903451912123195
# x33+x37+x38+x80 <= 1 added
# x_sum = 1.4304472166991726,len(ind_set) = 4 number_of_constraints  = 482, obj = 43.88967886902035
# x14+x53+x94+x113+x123 <= 1 added
# x_sum = 1.8117289003427555,len(ind_set) = 5 number_of_constraints  = 483, obj = 43.84933421197626
# x51+x64+x119+x137+x145 <= 1 added
# x_sum = 1.7970527134018124,len(ind_set) = 5 number_of_constraints  = 484, obj = 43.83069446294034
# x6+x82+x109+x160 <= 1 added
# x_sum = 1.3503590133549908,len(ind_set) = 4 number_of_constraints  = 485, obj = 43.81483036814807
# x9+x71+x104+x157 <= 1 added
# x_sum = 1.5135133893685557,len(ind_set) = 4 number_of_constraints  = 486, obj = 43.79952820642485
# x108+x149+x156+x181 <= 1 added
# x_sum = 1.5710312526654935,len(ind_set) = 4 number_of_constraints  = 487, obj = 43.79414452955656
# x35+x48+x94+x157 <= 1 added
# x_sum = 1.5411310938470724,len(ind_set) = 4 number_of_constraints  = 488, obj = 43.76759588930044
# x121+x147+x174+x199 <= 1 added
# x_sum = 1.4960272782049946,len(ind_set) = 4 number_of_constraints  = 489, obj = 43.74671445757335
# x3+x7+x143+x176 <= 1 added
# x_sum = 1.6107003816282992,len(ind_set) = 4 number_of_constraints  = 490, obj = 43.7375435389313
# x37+x103+x178 <= 1 added
# x_sum = 1.1424109806619913,len(ind_set) = 3 number_of_constraints  = 491, obj = 43.735370600846714
# x59+x77+x164+x173 <= 1 added
# x_sum = 1.4260402810641386,len(ind_set) = 4 number_of_constraints  = 492, obj = 43.7159875640151
# x22+x108+x175 <= 1 added
# x_sum = 1.3108716567984173,len(ind_set) = 3 number_of_constraints  = 493, obj = 43.704508401830445
# x18+x128+x182 <= 1 added
# x_sum = 1.3013583261127988,len(ind_set) = 3 number_of_constraints  = 494, obj = 43.69004494149367
# x12+x27+x132+x178 <= 1 added
# x_sum = 1.4783220035850244,len(ind_set) = 4 number_of_constraints  = 495, obj = 43.67369772891035
# x41+x169+x178+x190 <= 1 added
# x_sum = 1.444305801788858,len(ind_set) = 4 number_of_constraints  = 496, obj = 43.64674892655143
# x8+x12+x23+x128 <= 1 added
# x_sum = 1.3381527655446808,len(ind_set) = 4 number_of_constraints  = 497, obj = 43.63780675805621
# x41+x84+x159+x174 <= 1 added
# x_sum = 1.3195928622650464,len(ind_set) = 4 number_of_constraints  = 498, obj = 43.62276192597468
# x28+x46+x126+x179 <= 1 added
# x_sum = 1.2824981607058903,len(ind_set) = 4 number_of_constraints  = 499, obj = 43.617581769588405
# x58+x85+x88+x193 <= 1 added
# x_sum = 1.2625753482516175,len(ind_set) = 4 number_of_constraints  = 500, obj = 43.600484063236
# x9+x58+x73+x154 <= 1 added
# x_sum = 1.5083023258527994,len(ind_set) = 4 number_of_constraints  = 501, obj = 43.572087208872624
# x17+x28+x102+x116 <= 1 added
# x_sum = 1.2808253265987464,len(ind_set) = 4 number_of_constraints  = 502, obj = 43.55487508907584
# x97+x127+x134+x146 <= 1 added
# x_sum = 1.0507198224665637,len(ind_set) = 4 number_of_constraints  = 503, obj = 43.553930553339896
# x19+x94+x157+x177 <= 1 added
# x_sum = 1.3103044013790996,len(ind_set) = 4 number_of_constraints  = 504, obj = 43.53149405105688
# x135+x144+x170 <= 1 added
# x_sum = 1.210455721331579,len(ind_set) = 3 number_of_constraints  = 505, obj = 43.523809497342604
# x68+x144+x165 <= 1 added
# x_sum = 1.0970568917566177,len(ind_set) = 3 number_of_constraints  = 506, obj = 43.52137389368095
# x18+x63+x103+x143 <= 1 added
# x_sum = 1.300337267925944,len(ind_set) = 4 number_of_constraints  = 507, obj = 43.46977707832651
# x18+x97+x121+x164+x174 <= 1 added
# x_sum = 1.6766243162446548,len(ind_set) = 5 number_of_constraints  = 508, obj = 43.38252313011748
# x54+x103+x194 <= 1 added
# x_sum = 1.1298360756514376,len(ind_set) = 3 number_of_constraints  = 509, obj = 43.380998715830046
# x70+x148+x159+x177+x178 <= 1 added
# x_sum = 1.8021109904562034,len(ind_set) = 5 number_of_constraints  = 510, obj = 43.35482928884105
# x27+x78+x120+x179 <= 1 added
# x_sum = 1.396971569388624,len(ind_set) = 4 number_of_constraints  = 511, obj = 43.3354600135656
# x8+x88+x89+x128+x142 <= 1 added
# x_sum = 1.8706556362718576,len(ind_set) = 5 number_of_constraints  = 512, obj = 43.283974527598716
# x36+x83+x111+x141 <= 1 added
# x_sum = 1.5452311312324136,len(ind_set) = 4 number_of_constraints  = 513, obj = 43.24835210991272
# x17+x64+x138+x155 <= 1 added
# x_sum = 1.4708584198143673,len(ind_set) = 4 number_of_constraints  = 514, obj = 43.22743371459217
# x1+x17+x47+x82+x118 <= 1 added
# x_sum = 1.4296608186705175,len(ind_set) = 5 number_of_constraints  = 515, obj = 43.21481542447693
# x19+x22+x51+x180+x181 <= 1 added
# x_sum = 1.6144255174153321,len(ind_set) = 5 number_of_constraints  = 516, obj = 43.19732436580874
# x54+x103+x178 <= 1 added
# x_sum = 1.128188640273532,len(ind_set) = 3 number_of_constraints  = 517, obj = 43.19376106677717
# x23+x76+x87+x153 <= 1 added
# x_sum = 1.3473858335554099,len(ind_set) = 4 number_of_constraints  = 518, obj = 43.18929445258609
# x75+x88+x162+x193 <= 1 added
# x_sum = 1.4397768268470732,len(ind_set) = 4 number_of_constraints  = 519, obj = 43.17968484552863
# x20+x86+x103+x181 <= 1 added
# x_sum = 1.2454249616801745,len(ind_set) = 4 number_of_constraints  = 520, obj = 43.17512241050163
# x23+x92+x137+x185 <= 1 added
# x_sum = 1.3700231936137448,len(ind_set) = 4 number_of_constraints  = 521, obj = 43.16365512767577
# x43+x119+x173+x175+x184 <= 1 added
# x_sum = 1.4174306310346392,len(ind_set) = 5 number_of_constraints  = 522, obj = 43.149875614613684
# x38+x160+x175 <= 1 added
# x_sum = 1.186635234351542,len(ind_set) = 3 number_of_constraints  = 523, obj = 43.143754083158925
# x61+x103+x150+x161 <= 1 added
# x_sum = 1.3981629262269903,len(ind_set) = 4 number_of_constraints  = 524, obj = 43.11609684849092
# x17+x20+x56+x131+x137 <= 1 added
# x_sum = 1.459598403343238,len(ind_set) = 5 number_of_constraints  = 525, obj = 43.108556403701925
# x36+x151+x170+x188 <= 1 added
# x_sum = 1.5555012261384493,len(ind_set) = 4 number_of_constraints  = 526, obj = 43.08395691721008
# x35+x73+x116+x167 <= 1 added
# x_sum = 1.1599330681933002,len(ind_set) = 4 number_of_constraints  = 527, obj = 43.0810667375174
# x33+x63+x103+x117 <= 1 added
# x_sum = 1.1991778867085512,len(ind_set) = 4 number_of_constraints  = 528, obj = 43.07798118199352
# x30+x75+x126+x134+x153 <= 1 added
# x_sum = 1.3753752188755444,len(ind_set) = 5 number_of_constraints  = 529, obj = 43.049050403572416
# x35+x84+x107+x133 <= 1 added
# x_sum = 1.4212242440250196,len(ind_set) = 4 number_of_constraints  = 530, obj = 43.03231423863942
# x36+x104+x151+x176 <= 1 added
# x_sum = 1.4101854407064163,len(ind_set) = 4 number_of_constraints  = 531, obj = 43.021910651052906
# x16+x35+x42+x154 <= 1 added
# x_sum = 1.3259091020354,len(ind_set) = 4 number_of_constraints  = 532, obj = 43.016409611773966
# x31+x51+x87+x100+x143 <= 1 added
# x_sum = 1.308407004046824,len(ind_set) = 5 number_of_constraints  = 533, obj = 43.01094249306372
# x103+x117+x143+x161 <= 1 added
# x_sum = 1.1609331116354809,len(ind_set) = 4 number_of_constraints  = 534, obj = 43.0053416876207
# x30+x81+x109+x152 <= 1 added
# x_sum = 1.2887470919078103,len(ind_set) = 4 number_of_constraints  = 535, obj = 42.99874834783617
# x29+x53+x103 <= 1 added
# x_sum = 1.1080633915557745,len(ind_set) = 3 number_of_constraints  = 536, obj = 42.99730924277652
# x26+x74+x102+x193 <= 1 added
# x_sum = 1.1615842216042302,len(ind_set) = 4 number_of_constraints  = 537, obj = 42.995634079770205
# x101+x102+x147+x163+x182 <= 1 added
# x_sum = 1.4092499832422418,len(ind_set) = 5 number_of_constraints  = 538, obj = 42.96896900182362
# x11+x18+x26+x30 <= 1 added
# x_sum = 1.4808454789117174,len(ind_set) = 4 number_of_constraints  = 539, obj = 42.93177249327583
# x29+x53+x103 <= 1 added
# x_sum = 0.9999999999999999,len(ind_set) = 3 number_of_constraints  = 540, obj = 42.931772493275844
# x9+x72+x103+x126 <= 1 added
# x_sum = 1.716841556531539,len(ind_set) = 4 number_of_constraints  = 543, obj = 41.659031346520756
# x103+x142 <= 1 added
# x_sum = 1.3326971546037631,len(ind_set) = 2 number_of_constraints  = 544, obj = 41.61891597884295
# x103+x111 <= 1 added
# x_sum = 1.1830495606779217,len(ind_set) = 2 number_of_constraints  = 545, obj = 41.55048810705877
# x60+x103 <= 1 added
# x_sum = 1.1041420880883592,len(ind_set) = 2 number_of_constraints  = 546, obj = 41.539751226517986
# x12+x40+x89+x124 <= 1 added
# x_sum = 1.1113393233299742,len(ind_set) = 4 number_of_constraints  = 547, obj = 41.5355161043
# x1+x12+x52+x146+x147 <= 1 added
# x_sum = 1.3006163000729942,len(ind_set) = 5 number_of_constraints  = 548, obj = 41.51157681921878
# x103+x167+x196 <= 1 added
# x_sum = 1.061032774473892,len(ind_set) = 3 number_of_constraints  = 549, obj = 41.50260926546153
# x67+x84+x89+x124 <= 1 added
# x_sum = 1.2280359775995127,len(ind_set) = 4 number_of_constraints  = 550, obj = 41.48339713096945
# x48+x91+x118+x125 <= 1 added
# x_sum = 2.052962194670728,len(ind_set) = 4 number_of_constraints  = 553, obj = 40.2831763343041
# x1+x3+x125+x180 <= 1 added
# x_sum = 2.0389844880777304,len(ind_set) = 4 number_of_constraints  = 554, obj = 39.74065501936779
# x64+x102+x125+x162 <= 1 added
# x_sum = 1.9691047955105674,len(ind_set) = 4 number_of_constraints  = 555, obj = 39.45610727360562
# x125+x141+x154 <= 1 added
# x_sum = 1.775013678009372,len(ind_set) = 3 number_of_constraints  = 556, obj = 39.12719504341126
# x74+x125+x152 <= 1 added
# x_sum = 1.7987069620383447,len(ind_set) = 3 number_of_constraints  = 557, obj = 38.8136895904734
# x68+x125+x139 <= 1 added
# x_sum = 1.7290589545488717,len(ind_set) = 3 number_of_constraints  = 558, obj = 38.73504594317454
# x49+x75+x125 <= 1 added
# x_sum = 1.7304079296832937,len(ind_set) = 3 number_of_constraints  = 559, obj = 38.2935549659482
# x66+x97+x125 <= 1 added
# x_sum = 1.5765129256432318,len(ind_set) = 3 number_of_constraints  = 560, obj = 38.093213366191364
# x106+x125+x170 <= 1 added
# x_sum = 1.6460606704592018,len(ind_set) = 3 number_of_constraints  = 561, obj = 38.0373753047311
# x88+x125+x137 <= 1 added
# x_sum = 1.4093640210904161,len(ind_set) = 3 number_of_constraints  = 562, obj = 37.94217405602306
# x50+x103 <= 1 added
# x_sum = 1.3715483312745476,len(ind_set) = 2 number_of_constraints  = 563, obj = 37.85005539540839
# x44+x125 <= 1 added
# x_sum = 1.3090691783545603,len(ind_set) = 2 number_of_constraints  = 564, obj = 37.69499112702753
# x125+x157 <= 1 added
# x_sum = 1.2560980148601897,len(ind_set) = 2 number_of_constraints  = 565, obj = 37.654288148049865
# x7+x125 <= 1 added
# x_sum = 1.2130322073781359,len(ind_set) = 2 number_of_constraints  = 566, obj = 37.59790283419533
# x78+x109+x125 <= 1 added
# x_sum = 1.1995250905036108,len(ind_set) = 3 number_of_constraints  = 567, obj = 37.55285269509306
# x14+x76+x146+x164 <= 1 added
# x_sum = 1.829463933586112,len(ind_set) = 4 number_of_constraints  = 568, obj = 37.22598935817281
# x125+x184 <= 1 added
# x_sum = 1.0967230002220252,len(ind_set) = 2 number_of_constraints  = 569, obj = 37.22598935817281
# x23+x125 <= 1 added
# x_sum = 1.0146014903890772,len(ind_set) = 2 number_of_constraints  = 570, obj = 37.225434177366544
# x10+x39+x71+x84+x116 <= 1 added
# x_sum = 2.3773475322600692,len(ind_set) = 5 number_of_constraints  = 572, obj = 36.307075715815955
# x10+x101+x187 <= 1 added
# x_sum = 1.7345261163427657,len(ind_set) = 3 number_of_constraints  = 573, obj = 36.05181715874487
# x10+x73+x132 <= 1 added
# x_sum = 1.8113166953528392,len(ind_set) = 3 number_of_constraints  = 574, obj = 35.493042133745654
# x10+x99+x169 <= 1 added
# x_sum = 1.7642056436026283,len(ind_set) = 3 number_of_constraints  = 575, obj = 35.12023460410557
# x10+x151+x158 <= 1 added
# x_sum = 1.532258064516129,len(ind_set) = 3 number_of_constraints  = 576, obj = 34.79172610556348
# x10+x177 <= 1 added
# x_sum = 1.2786495482643843,len(ind_set) = 2 number_of_constraints  = 577, obj = 34.74968394437421
# x10+x119 <= 1 added
# x_sum = 1.276864728192162,len(ind_set) = 2 number_of_constraints  = 578, obj = 34.62123385939742
# x10+x173 <= 1 added
# x_sum = 1.2266857962697277,len(ind_set) = 2 number_of_constraints  = 579, obj = 34.54819277108434
# x10+x45+x93 <= 1 added
# x_sum = 1.3072289156626506,len(ind_set) = 3 number_of_constraints  = 580, obj = 34.54020979020979
# x10+x114 <= 1 added
# x_sum = 1.0804195804195804,len(ind_set) = 2 number_of_constraints  = 581, obj = 34.53099539496989
# x10+x100 <= 1 added
# x_sum = 1.0928090683669853,len(ind_set) = 2 number_of_constraints  = 582, obj = 34.52463768115941
# x5+x52+x134+x146 <= 1 added
# x_sum = 1.0404912047792898,len(ind_set) = 4 number_of_constraints  = 584, obj = 34.51807228915663
# x14+x67+x90+x146 <= 1 added
# x_sum = 1.9286150091519216,len(ind_set) = 4 number_of_constraints  = 586, obj = 34.0625
# x8+x26+x153+x197 <= 1 added
# x_sum = 2.5625,len(ind_set) = 4 number_of_constraints  = 587, obj = 33.52631578947368
# x10+x123 <= 1 added
# x_sum = 1.0526315789473686,len(ind_set) = 2 number_of_constraints  = 588, obj = 33.50000000000001
# x11+x145+x168 <= 1 added
# x_sum = 2.0344827586206895,len(ind_set) = 3 number_of_constraints  = 590, obj = 32.0
# x124+x133+x134 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 591, obj = 32.0
# x11+x107+x112+x171 <= 1 added
# x_sum = 2.75,len(ind_set) = 4 number_of_constraints  = 592, obj = 31.083333333333336
# x11+x120+x172 <= 1 added
# x_sum = 1.9166666666666667,len(ind_set) = 3 number_of_constraints  = 593, obj = 30.5
# x11+x47+x148 <= 1 added
# x_sum = 1.375,len(ind_set) = 3 number_of_constraints  = 594, obj = 30.400000000000002
# x10+x110 <= 1 added
# x_sum = 1.4,len(ind_set) = 2 number_of_constraints  = 595, obj = 30.400000000000002
# x11+x191 <= 1 added
# x_sum = 1.2,len(ind_set) = 2 number_of_constraints  = 596, obj = 30.25
# x133+x188 <= 1 added
# x_sum = 1.75,len(ind_set) = 2 number_of_constraints  = 597, obj = 30.0
# x21+x51+x81 <= 1 added
# x_sum = 2.0,len(ind_set) = 3 number_of_constraints  = 598, obj = 29.833333333333332
# x5+x27+x67+x80 <= 1 added
# x_sum = 1.8333333333333335,len(ind_set) = 4 number_of_constraints  = 599, obj = 29.571428571428573
# x11+x140 <= 1 added
# x_sum = 1.2857142857142856,len(ind_set) = 2 number_of_constraints  = 600, obj = 29.500000000000007
# x10+x192 <= 1 added
# x_sum = 1.3333333333333333,len(ind_set) = 2 number_of_constraints  = 601, obj = 29.25
# x11+x77 <= 1 added
# x_sum = 1.25,len(ind_set) = 2 number_of_constraints  = 602, obj = 29.166666666666664
# x38+x81 <= 1 added
# x_sum = 1.7777777777777781,len(ind_set) = 2 number_of_constraints  = 604, obj = 28.0
# x5+x52+x70 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 605, obj = 28.0
# x38+x52+x124+x131 <= 1 added
# x_sum = 2.5,len(ind_set) = 4 number_of_constraints  = 606, obj = 27.600000000000005
# x13+x38 <= 1 added
# x_sum = 2.0,len(ind_set) = 2 number_of_constraints  = 607, obj = 26.857142857142854
# x42+x43+x65+x90+x146 <= 1 added
# x_sum = 2.2857142857142856,len(ind_set) = 5 number_of_constraints  = 608, obj = 26.5
# x59+x98+x108 <= 1 added
# x_sum = 2.5,len(ind_set) = 3 number_of_constraints  = 609, obj = 25.833333333333332
# x14+x25+x51 <= 1 added
# x_sum = 2.0,len(ind_set) = 3 number_of_constraints  = 610, obj = 25.5
# x21+x197 <= 1 added
# x_sum = 2.0,len(ind_set) = 2 number_of_constraints  = 611, obj = 25.5
# x14+x104 <= 1 added
# x_sum = 2.0,len(ind_set) = 2 number_of_constraints  = 612, obj = 24.666666666666668
# x38+x82+x105 <= 1 added
# x_sum = 2.0,len(ind_set) = 3 number_of_constraints  = 613, obj = 24.083333333333336
# x38+x79 <= 1 added
# x_sum = 1.3333333333333333,len(ind_set) = 2 number_of_constraints  = 614, obj = 24.041666666666664
# x70+x104 <= 1 added
# x70+x104 <= 1 makes no solution
# x5+x188 <= 1 added
# x_sum = 2.0,len(ind_set) = 2 number_of_constraints  = 619, obj = 22.5
# x5+x59 <= 1 added
# x_sum = 2.0,len(ind_set) = 2 number_of_constraints  = 620, obj = 22.0
# solution int
# (22, 65) are not neighbours. Not a clique
# (22, 65) are not neighbours. Added x22+x65 <= 1
# (22, 69) are not neighbours. Added x22+x69 <= 1
# (22, 133) are not neighbours. Added x22+x133 <= 1
# (22, 147) are not neighbours. Added x22+x147 <= 1
# (32, 133) are not neighbours. Added x32+x133 <= 1
# (46, 92) are not neighbours. Added x46+x92 <= 1
# (46, 159) are not neighbours. Added x46+x159 <= 1
# (57, 115) are not neighbours. Added x57+x115 <= 1
# (65, 22) are not neighbours. Added x22+x65 <= 1
# (69, 22) are not neighbours. Added x22+x69 <= 1
# (69, 104) are not neighbours. Added x69+x104 <= 1
# (69, 115) are not neighbours. Added x69+x115 <= 1
# (69, 127) are not neighbours. Added x69+x127 <= 1
# (92, 46) are not neighbours. Added x46+x92 <= 1
# (92, 159) are not neighbours. Added x92+x159 <= 1
# (92, 197) are not neighbours. Added x92+x197 <= 1
# (95, 133) are not neighbours. Added x95+x133 <= 1
# (95, 147) are not neighbours. Added x95+x147 <= 1
# (95, 159) are not neighbours. Added x95+x159 <= 1
# (104, 69) are not neighbours. Added x69+x104 <= 1
# (104, 159) are not neighbours. Added x104+x159 <= 1
# (115, 57) are not neighbours. Added x57+x115 <= 1
# (115, 69) are not neighbours. Added x69+x115 <= 1
# (127, 69) are not neighbours. Added x69+x127 <= 1
# (133, 22) are not neighbours. Added x22+x133 <= 1
# (133, 32) are not neighbours. Added x32+x133 <= 1
# (133, 95) are not neighbours. Added x95+x133 <= 1
# (147, 22) are not neighbours. Added x22+x147 <= 1
# (147, 95) are not neighbours. Added x95+x147 <= 1
# (159, 46) are not neighbours. Added x46+x159 <= 1
# (159, 92) are not neighbours. Added x92+x159 <= 1
# (159, 95) are not neighbours. Added x95+x159 <= 1
# (159, 104) are not neighbours. Added x104+x159 <= 1
# (159, 197) are not neighbours. Added x159+x197 <= 1
# (197, 92) are not neighbours. Added x92+x197 <= 1
# (197, 159) are not neighbours. Added x159+x197 <= 1
# x25+x41 <= 1 added
# x_sum = 1.6666666666666665,len(ind_set) = 2 number_of_constraints  = 657, obj = 23.0
# solution int
# (22, 28) are not neighbours. Not a clique
# (22, 28) are not neighbours. Added x22+x28 <= 1
# (28, 22) are not neighbours. Added x22+x28 <= 1
# (28, 57) are not neighbours. Added x28+x57 <= 1
# (28, 189) are not neighbours. Added x28+x189 <= 1
# (38, 94) are not neighbours. Added x38+x94 <= 1
# (41, 42) are not neighbours. Added x41+x42 <= 1
# (41, 57) are not neighbours. Added x41+x57 <= 1
# (42, 41) are not neighbours. Added x41+x42 <= 1
# (42, 57) are not neighbours. Added x42+x57 <= 1
# (57, 28) are not neighbours. Added x28+x57 <= 1
# (57, 41) are not neighbours. Added x41+x57 <= 1
# (57, 42) are not neighbours. Added x42+x57 <= 1
# (67, 104) are not neighbours. Added x67+x104 <= 1
# (67, 188) are not neighbours. Added x67+x188 <= 1
# (67, 189) are not neighbours. Added x67+x189 <= 1
# (67, 197) are not neighbours. Added x67+x197 <= 1
# (94, 38) are not neighbours. Added x38+x94 <= 1
# (94, 98) are not neighbours. Added x94+x98 <= 1
# (94, 127) are not neighbours. Added x94+x127 <= 1
# (94, 189) are not neighbours. Added x94+x189 <= 1
# (98, 94) are not neighbours. Added x94+x98 <= 1
# (98, 127) are not neighbours. Added x98+x127 <= 1
# (98, 144) are not neighbours. Added x98+x144 <= 1
# (98, 156) are not neighbours. Added x98+x156 <= 1
# (98, 182) are not neighbours. Added x98+x182 <= 1
# (104, 67) are not neighbours. Added x67+x104 <= 1
# (104, 156) are not neighbours. Added x104+x156 <= 1
# (122, 182) are not neighbours. Added x122+x182 <= 1
# (125, 189) are not neighbours. Added x125+x189 <= 1
# (127, 94) are not neighbours. Added x94+x127 <= 1
# (127, 98) are not neighbours. Added x98+x127 <= 1
# (144, 98) are not neighbours. Added x98+x144 <= 1
# (144, 189) are not neighbours. Added x144+x189 <= 1
# (156, 98) are not neighbours. Added x98+x156 <= 1
# (156, 104) are not neighbours. Added x104+x156 <= 1
# (182, 98) are not neighbours. Added x98+x182 <= 1
# (182, 122) are not neighbours. Added x122+x182 <= 1
# (188, 67) are not neighbours. Added x67+x188 <= 1
# (188, 197) are not neighbours. Added x188+x197 <= 1
# (189, 28) are not neighbours. Added x28+x189 <= 1
# (189, 67) are not neighbours. Added x67+x189 <= 1
# (189, 94) are not neighbours. Added x94+x189 <= 1
# (189, 125) are not neighbours. Added x125+x189 <= 1
# (189, 144) are not neighbours. Added x144+x189 <= 1
# (197, 67) are not neighbours. Added x67+x197 <= 1
# (197, 188) are not neighbours. Added x188+x197 <= 1
# x41+x62+x134 <= 1 added
# x_sum = 1.25,len(ind_set) = 3 number_of_constraints  = 703, obj = 20.5
# x13+x76+x80 <= 1 added
# x_sum = 2.5,len(ind_set) = 3 number_of_constraints  = 702, obj = 24.5
# x5+x43 <= 1 added
# x_sum = 1.5,len(ind_set) = 2 number_of_constraints  = 704, obj = 23.5
# x5+x94 <= 1 added
# x_sum = 1.5,len(ind_set) = 2 number_of_constraints  = 705, obj = 23.5
# x5+x105 <= 1 added
# x_sum = 1.5,len(ind_set) = 2 number_of_constraints  = 706, obj = 23.0
# solution int
# (13, 22) are not neighbours. Not a clique
# (13, 22) are not neighbours. Added x13+x22 <= 1
# (13, 95) are not neighbours. Added x13+x95 <= 1
# (13, 179) are not neighbours. Added x13+x179 <= 1
# (13, 182) are not neighbours. Added x13+x182 <= 1
# (13, 195) are not neighbours. Added x13+x195 <= 1
# (22, 13) are not neighbours. Added x13+x22 <= 1
# (22, 81) are not neighbours. Added x22+x81 <= 1
# (42, 81) are not neighbours. Added x42+x81 <= 1
# (62, 197) are not neighbours. Added x62+x197 <= 1
# (81, 22) are not neighbours. Added x22+x81 <= 1
# (81, 42) are not neighbours. Added x42+x81 <= 1
# (81, 121) are not neighbours. Added x81+x121 <= 1
# (81, 144) are not neighbours. Added x81+x144 <= 1
# (81, 195) are not neighbours. Added x81+x195 <= 1
# (82, 95) are not neighbours. Added x82+x95 <= 1
# (95, 13) are not neighbours. Added x13+x95 <= 1
# (95, 82) are not neighbours. Added x82+x95 <= 1
# (104, 179) are not neighbours. Added x104+x179 <= 1
# (121, 81) are not neighbours. Added x81+x121 <= 1
# (124, 166) are not neighbours. Added x124+x166 <= 1
# (124, 182) are not neighbours. Added x124+x182 <= 1
# (124, 195) are not neighbours. Added x124+x195 <= 1
# (144, 81) are not neighbours. Added x81+x144 <= 1
# (166, 124) are not neighbours. Added x124+x166 <= 1
# (166, 179) are not neighbours. Added x166+x179 <= 1
# (179, 13) are not neighbours. Added x13+x179 <= 1
# (179, 104) are not neighbours. Added x104+x179 <= 1
# (179, 166) are not neighbours. Added x166+x179 <= 1
# (179, 182) are not neighbours. Added x179+x182 <= 1
# (182, 13) are not neighbours. Added x13+x182 <= 1
# (182, 124) are not neighbours. Added x124+x182 <= 1
# (182, 179) are not neighbours. Added x179+x182 <= 1
# (195, 13) are not neighbours. Added x13+x195 <= 1
# (195, 81) are not neighbours. Added x81+x195 <= 1
# (195, 124) are not neighbours. Added x124+x195 <= 1
# (197, 62) are not neighbours. Added x62+x197 <= 1
# solution int
# (31, 46) are not neighbours. Not a clique
# (31, 46) are not neighbours. Added x31+x46 <= 1
# (31, 76) are not neighbours. Added x31+x76 <= 1
# (31, 122) are not neighbours. Added x31+x122 <= 1
# (31, 131) are not neighbours. Added x31+x131 <= 1
# (41, 65) are not neighbours. Added x41+x65 <= 1
# (41, 76) are not neighbours. Added x41+x76 <= 1
# (41, 131) are not neighbours. Added x41+x131 <= 1
# (41, 165) are not neighbours. Added x41+x165 <= 1
# (46, 31) are not neighbours. Added x31+x46 <= 1
# (46, 76) are not neighbours. Added x46+x76 <= 1
# (46, 131) are not neighbours. Added x46+x131 <= 1
# (65, 41) are not neighbours. Added x41+x65 <= 1
# (65, 195) are not neighbours. Added x65+x195 <= 1
# (76, 31) are not neighbours. Added x31+x76 <= 1
# (76, 41) are not neighbours. Added x41+x76 <= 1
# (76, 46) are not neighbours. Added x46+x76 <= 1
# (76, 104) are not neighbours. Added x76+x104 <= 1
# (76, 127) are not neighbours. Added x76+x127 <= 1
# (76, 147) are not neighbours. Added x76+x147 <= 1
# (76, 165) are not neighbours. Added x76+x165 <= 1
# (76, 175) are not neighbours. Added x76+x175 <= 1
# (104, 76) are not neighbours. Added x76+x104 <= 1
# (122, 31) are not neighbours. Added x31+x122 <= 1
# (127, 76) are not neighbours. Added x76+x127 <= 1
# (131, 31) are not neighbours. Added x31+x131 <= 1
# (131, 41) are not neighbours. Added x41+x131 <= 1
# (131, 46) are not neighbours. Added x46+x131 <= 1
# (131, 147) are not neighbours. Added x131+x147 <= 1
# (131, 165) are not neighbours. Added x131+x165 <= 1
# (147, 76) are not neighbours. Added x76+x147 <= 1
# (147, 131) are not neighbours. Added x131+x147 <= 1
# (147, 195) are not neighbours. Added x147+x195 <= 1
# (165, 41) are not neighbours. Added x41+x165 <= 1
# (165, 76) are not neighbours. Added x76+x165 <= 1
# (165, 131) are not neighbours. Added x131+x165 <= 1
# (175, 76) are not neighbours. Added x76+x175 <= 1
# (195, 65) are not neighbours. Added x65+x195 <= 1
# (195, 147) are not neighbours. Added x147+x195 <= 1
# x25+x46+x52 <= 1 added
# x_sum = 3.0,len(ind_set) = 3 number_of_constraints  = 784, obj = 20.5
# x51+x121 <= 1 added
# x_sum = 2.0,len(ind_set) = 2 number_of_constraints  = 785, obj = 20.0
# x134+x146+x166 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 786, obj = 19.5
# x146+x147+x195 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 787, obj = 21.5
# x134+x146+x165+x166 <= 1 added
# x_sum = 1.25,len(ind_set) = 4 number_of_constraints  = 789, obj = 20.5
# x25+x41+x95 <= 1 added
# x_sum = 1.3333333333333335,len(ind_set) = 3 number_of_constraints  = 791, obj = 20.666666666666668
# x25+x41+x131 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 789, obj = 21.399999999999988
# x52+x127+x134+x146 <= 1 added
# x_sum = 1.125,len(ind_set) = 4 number_of_constraints  = 793, obj = 20.5
# x52+x124+x127+x134 <= 1 added
# x_sum = 1.4000000000000004,len(ind_set) = 4 number_of_constraints  = 792, obj = 20.714285714285715
# x41+x43+x95 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 793, obj = 21.5
# x41+x43+x65 <= 1 added
# x_sum = 1.1666666666666665,len(ind_set) = 3 number_of_constraints  = 797, obj = 20.666666666666668
# x124+x127+x134+x166 <= 1 added
# x_sum = 1.6666666666666667,len(ind_set) = 4 number_of_constraints  = 800, obj = 20.0
# solution int
# (32, 51) are not neighbours. Not a clique
# (32, 51) are not neighbours. Added x32+x51 <= 1
# (32, 105) are not neighbours. Added x32+x105 <= 1
# (46, 166) are not neighbours. Added x46+x166 <= 1
# (46, 182) are not neighbours. Added x46+x182 <= 1
# (51, 32) are not neighbours. Added x32+x51 <= 1
# (51, 197) are not neighbours. Added x51+x197 <= 1
# (59, 80) are not neighbours. Added x59+x80 <= 1
# (80, 59) are not neighbours. Added x59+x80 <= 1
# (80, 105) are not neighbours. Added x80+x105 <= 1
# (80, 175) are not neighbours. Added x80+x175 <= 1
# (94, 95) are not neighbours. Added x94+x95 <= 1
# (95, 94) are not neighbours. Added x94+x95 <= 1
# (104, 105) are not neighbours. Added x104+x105 <= 1
# (105, 32) are not neighbours. Added x32+x105 <= 1
# (105, 80) are not neighbours. Added x80+x105 <= 1
# (105, 104) are not neighbours. Added x104+x105 <= 1
# (105, 144) are not neighbours. Added x105+x144 <= 1
# (105, 166) are not neighbours. Added x105+x166 <= 1
# (144, 105) are not neighbours. Added x105+x144 <= 1
# (166, 46) are not neighbours. Added x46+x166 <= 1
# (166, 105) are not neighbours. Added x105+x166 <= 1
# (175, 80) are not neighbours. Added x80+x175 <= 1
# (182, 46) are not neighbours. Added x46+x182 <= 1
# (197, 51) are not neighbours. Added x51+x197 <= 1
# solution int
# (13, 65) are not neighbours. Not a clique
# (13, 65) are not neighbours. Added x13+x65 <= 1
# (13, 193) are not neighbours. Added x13+x193 <= 1
# (15, 28) are not neighbours. Added x15+x28 <= 1
# (15, 32) are not neighbours. Added x15+x32 <= 1
# (15, 104) are not neighbours. Added x15+x104 <= 1
# (15, 193) are not neighbours. Added x15+x193 <= 1
# (28, 15) are not neighbours. Added x15+x28 <= 1
# (28, 82) are not neighbours. Added x28+x82 <= 1
# (28, 124) are not neighbours. Added x28+x124 <= 1
# (31, 124) are not neighbours. Added x31+x124 <= 1
# (31, 193) are not neighbours. Added x31+x193 <= 1
# (32, 15) are not neighbours. Added x15+x32 <= 1
# (32, 168) are not neighbours. Added x32+x168 <= 1
# (65, 13) are not neighbours. Added x13+x65 <= 1
# (65, 121) are not neighbours. Added x65+x121 <= 1
# (82, 28) are not neighbours. Added x28+x82 <= 1
# (104, 15) are not neighbours. Added x15+x104 <= 1
# (104, 112) are not neighbours. Added x104+x112 <= 1
# (112, 104) are not neighbours. Added x104+x112 <= 1
# (112, 168) are not neighbours. Added x112+x168 <= 1
# (121, 65) are not neighbours. Added x65+x121 <= 1
# (121, 140) are not neighbours. Added x121+x140 <= 1
# (124, 28) are not neighbours. Added x28+x124 <= 1
# (124, 31) are not neighbours. Added x31+x124 <= 1
# (124, 140) are not neighbours. Added x124+x140 <= 1
# (140, 121) are not neighbours. Added x121+x140 <= 1
# (140, 124) are not neighbours. Added x124+x140 <= 1
# (168, 32) are not neighbours. Added x32+x168 <= 1
# (168, 112) are not neighbours. Added x112+x168 <= 1
# (193, 13) are not neighbours. Added x13+x193 <= 1
# (193, 15) are not neighbours. Added x15+x193 <= 1
# (193, 31) are not neighbours. Added x31+x193 <= 1
# x5+x58 <= 1 added
# x_sum = 2.0,len(ind_set) = 2 number_of_constraints  = 850, obj = 20.333333333333336
# x13+x107+x148 <= 1 added
# x13+x107+x148 <= 1 makes no solution
# x13+x41 <= 1 added
# x13+x41 <= 1 makes no solution
# x58+x85+x121 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 858, obj = 20.0
# solution int
# (13, 122) are not neighbours. Not a clique
# (13, 122) are not neighbours. Added x13+x122 <= 1
# (13, 127) are not neighbours. Added x13+x127 <= 1
# (19, 85) are not neighbours. Added x19+x85 <= 1
# (27, 77) are not neighbours. Added x27+x77 <= 1
# (27, 122) are not neighbours. Added x27+x122 <= 1
# (32, 77) are not neighbours. Added x32+x77 <= 1
# (42, 79) are not neighbours. Added x42+x79 <= 1
# (42, 191) are not neighbours. Added x42+x191 <= 1
# (56, 191) are not neighbours. Added x56+x191 <= 1
# (77, 27) are not neighbours. Added x27+x77 <= 1
# (77, 32) are not neighbours. Added x32+x77 <= 1
# (77, 104) are not neighbours. Added x77+x104 <= 1
# (77, 122) are not neighbours. Added x77+x122 <= 1
# (77, 183) are not neighbours. Added x77+x183 <= 1
# (77, 191) are not neighbours. Added x77+x191 <= 1
# (79, 42) are not neighbours. Added x42+x79 <= 1
# (79, 191) are not neighbours. Added x79+x191 <= 1
# (85, 19) are not neighbours. Added x19+x85 <= 1
# (85, 122) are not neighbours. Added x85+x122 <= 1
# (85, 160) are not neighbours. Added x85+x160 <= 1
# (104, 77) are not neighbours. Added x77+x104 <= 1
# (104, 108) are not neighbours. Added x104+x108 <= 1
# (108, 104) are not neighbours. Added x104+x108 <= 1
# (122, 13) are not neighbours. Added x13+x122 <= 1
# (122, 27) are not neighbours. Added x27+x122 <= 1
# (122, 77) are not neighbours. Added x77+x122 <= 1
# (122, 85) are not neighbours. Added x85+x122 <= 1
# (122, 183) are not neighbours. Added x122+x183 <= 1
# (127, 13) are not neighbours. Added x13+x127 <= 1
# (127, 183) are not neighbours. Added x127+x183 <= 1
# (127, 191) are not neighbours. Added x127+x191 <= 1
# (160, 85) are not neighbours. Added x85+x160 <= 1
# (183, 77) are not neighbours. Added x77+x183 <= 1
# (183, 122) are not neighbours. Added x122+x183 <= 1
# (183, 127) are not neighbours. Added x127+x183 <= 1
# (183, 191) are not neighbours. Added x183+x191 <= 1
# (191, 42) are not neighbours. Added x42+x191 <= 1
# (191, 56) are not neighbours. Added x56+x191 <= 1
# (191, 77) are not neighbours. Added x77+x191 <= 1
# (191, 79) are not neighbours. Added x79+x191 <= 1
# (191, 127) are not neighbours. Added x127+x191 <= 1
# (191, 183) are not neighbours. Added x183+x191 <= 1
# x52+x146+x160 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 898, obj = 20.333333333333336
# x52+x134+x146+x160 <= 1 added
# x_sum = 1.09375,len(ind_set) = 4 number_of_constraints  = 898, obj = 21.666666666666675
# x13+x145 <= 1 added
# x13+x145 <= 1 makes no solution
# x145+x197 <= 1 added
# x145+x197 <= 1 makes no solution
# x5+x85+x148 <= 1 added
# x_sum = 1.25,len(ind_set) = 3 number_of_constraints  = 899, obj = 25.875
# x35+x171 <= 1 added
# x_sum = 2.0,len(ind_set) = 2 number_of_constraints  = 902, obj = 23.0
# x35+x197 <= 1 added
# x35+x197 <= 1 makes no solution
# x19+x89 <= 1 added
# x_sum = 1.6,len(ind_set) = 2 number_of_constraints  = 904, obj = 24.0
# x41+x134+x171 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 905, obj = 24.0
# x47+x81+x148 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 909, obj = 21.0
# x121+x148 <= 1 added
# x_sum = 1.3333333333333335,len(ind_set) = 2 number_of_constraints  = 912, obj = 20.25
# x31+x80 <= 1 added
# x_sum = 1.5,len(ind_set) = 2 number_of_constraints  = 910, obj = 21.0
# x31+x56 <= 1 added
# x_sum = 1.5,len(ind_set) = 2 number_of_constraints  = 911, obj = 20.5
# x47+x124+x171 <= 1 added
# x_sum = 2.0,len(ind_set) = 3 number_of_constraints  = 917, obj = 21.0
# x124+x127+x183 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 919, obj = 20.5
# x80+x140 <= 1 added
# x_sum = 2.0,len(ind_set) = 2 number_of_constraints  = 916, obj = 20.5
# x80+x121 <= 1 added
# x_sum = 1.5,len(ind_set) = 2 number_of_constraints  = 917, obj = 20.5
# x80+x193 <= 1 added
# x_sum = 1.5,len(ind_set) = 2 number_of_constraints  = 918, obj = 20.5
# x80+x191 <= 1 added
# x_sum = 1.5,len(ind_set) = 2 number_of_constraints  = 919, obj = 20.0
# x80+x172 <= 1 added
# x_sum = 1.5,len(ind_set) = 2 number_of_constraints  = 920, obj = 20.0
# solution int
# (32, 52) are not neighbours. Not a clique
# (32, 52) are not neighbours. Added x32+x52 <= 1
# (52, 32) are not neighbours. Added x32+x52 <= 1
# (65, 120) are not neighbours. Added x65+x120 <= 1
# (79, 98) are not neighbours. Added x79+x98 <= 1
# (79, 120) are not neighbours. Added x79+x120 <= 1
# (95, 120) are not neighbours. Added x95+x120 <= 1
# (98, 79) are not neighbours. Added x79+x98 <= 1
# (115, 120) are not neighbours. Added x115+x120 <= 1
# (115, 171) are not neighbours. Added x115+x171 <= 1
# (120, 65) are not neighbours. Added x65+x120 <= 1
# (120, 79) are not neighbours. Added x79+x120 <= 1
# (120, 95) are not neighbours. Added x95+x120 <= 1
# (120, 115) are not neighbours. Added x115+x120 <= 1
# (148, 165) are not neighbours. Added x148+x165 <= 1
# (165, 148) are not neighbours. Added x148+x165 <= 1
# (171, 115) are not neighbours. Added x115+x171 <= 1
# x41+x42+x171 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 939, obj = 21.0
# x89+x104 <= 1 added
# x_sum = 1.625,len(ind_set) = 2 number_of_constraints  = 933, obj = 24.35135135135135
# x5+x171 <= 1 added
# x_sum = 1.25,len(ind_set) = 2 number_of_constraints  = 936, obj = 21.666666666666664
# x25+x47+x148 <= 1 added
# x_sum = 2.0,len(ind_set) = 3 number_of_constraints  = 939, obj = 20.25
# x120+x146+x195 <= 1 added
# x_sum = 2.0,len(ind_set) = 3 number_of_constraints  = 940, obj = 19.799999999999997
# x25+x107 <= 1 added
# x_sum = 1.7,len(ind_set) = 2 number_of_constraints  = 941, obj = 19.25
# x25+x193 <= 1 added
# x_sum = 1.5,len(ind_set) = 2 number_of_constraints  = 942, obj = 18.8
# x41+x85+x148+x160 <= 1 added
# x_sum = 1.5,len(ind_set) = 4 number_of_constraints  = 943, obj = 20.5
# x28+x148 <= 1 added
# x_sum = 1.5,len(ind_set) = 2 number_of_constraints  = 944, obj = 20.25
# x25+x81+x107+x148 <= 1 added
# x_sum = 1.75,len(ind_set) = 4 number_of_constraints  = 945, obj = 21.5
# x41+x59+x148+x160 <= 1 added
# x_sum = 1.25,len(ind_set) = 4 number_of_constraints  = 948, obj = 21.0
# x41+x43+x131 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 949, obj = 21.0
# x41+x43+x160 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 951, obj = 20.875
# x81+x121+x148 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 955, obj = 20.0
# x5+x94+x98 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 947, obj = 23.5
# x28+x90+x147 <= 1 added
# x_sum = 2.0,len(ind_set) = 3 number_of_constraints  = 951, obj = 20.25
# x147+x171 <= 1 added
# x_sum = 1.0833333333333333,len(ind_set) = 2 number_of_constraints  = 952, obj = 20.25
# x98+x107 <= 1 added
# x_sum = 2.0,len(ind_set) = 2 number_of_constraints  = 954, obj = 20.5
# x41+x57+x134 <= 1 added
# x_sum = 1.5,len(ind_set) = 3 number_of_constraints  = 957, obj = 20.333333333333332
# x107+x134 <= 1 added
# x_sum = 1.333333333333333,len(ind_set) = 2 number_of_constraints  = 958, obj = 20.166666666666675
# x95+x107 <= 1 added
# x_sum = 1.5,len(ind_set) = 2 number_of_constraints  = 959, obj = 19.666666666666668
# x41+x42+x65 <= 1 added
# x_sum = 1.3333333333333333,len(ind_set) = 3 number_of_constraints  = 960, obj = 19.5
# x127+x146+x166 <= 1 added
# x_sum = 1.25,len(ind_set) = 3 number_of_constraints  = 959, obj = 21.235294117647058
# ----------------- Python exception: <built-in function delete_doublePtr> returned a result with an error set
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\users\andru\appdata\local\programs\python\python37\lib\site-packages\cplex\_internal\_pycplex.py in __init__(self)
#    3266     def __init__(self):
# -> 3267         this = _pycplex_platform.new_doublePtr()
#    3268         try: self.this.append(this)
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-844-6170e58594d3> in <module>
# ----> 1 branch_and_cut_search(sum_without_random = 2)
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      33         con2 = x[fraction_variable_index] <= 0
#      34         mdl.add_constraint(con1)
# ---> 35         branch_and_cut_search()
#      36         mdl.remove_constraint(con1)
#      37
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      33         con2 = x[fraction_variable_index] <= 0
#      34         mdl.add_constraint(con1)
# ---> 35         branch_and_cut_search()
#      36         mdl.remove_constraint(con1)
#      37
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      33         con2 = x[fraction_variable_index] <= 0
#      34         mdl.add_constraint(con1)
# ---> 35         branch_and_cut_search()
#      36         mdl.remove_constraint(con1)
#      37
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      33         con2 = x[fraction_variable_index] <= 0
#      34         mdl.add_constraint(con1)
# ---> 35         branch_and_cut_search()
#      36         mdl.remove_constraint(con1)
#      37
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      33         con2 = x[fraction_variable_index] <= 0
#      34         mdl.add_constraint(con1)
# ---> 35         branch_and_cut_search()
#      36         mdl.remove_constraint(con1)
#      37
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      33         con2 = x[fraction_variable_index] <= 0
#      34         mdl.add_constraint(con1)
# ---> 35         branch_and_cut_search()
#      36         mdl.remove_constraint(con1)
#      37
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      37
#      38         mdl.add_constraint(con2)
# ---> 39         branch_and_cut_search()
#      40         mdl.remove_constraint(con2)
#      41     else: # solution is int
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      37
#      38         mdl.add_constraint(con2)
# ---> 39         branch_and_cut_search()
#      40         mdl.remove_constraint(con2)
#      41     else: # solution is int
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      37
#      38         mdl.add_constraint(con2)
# ---> 39         branch_and_cut_search()
#      40         mdl.remove_constraint(con2)
#      41     else: # solution is int
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      37
#      38         mdl.add_constraint(con2)
# ---> 39         branch_and_cut_search()
#      40         mdl.remove_constraint(con2)
#      41     else: # solution is int
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      37
#      38         mdl.add_constraint(con2)
# ---> 39         branch_and_cut_search()
#      40         mdl.remove_constraint(con2)
#      41     else: # solution is int
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      33         con2 = x[fraction_variable_index] <= 0
#      34         mdl.add_constraint(con1)
# ---> 35         branch_and_cut_search()
#      36         mdl.remove_constraint(con1)
#      37
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      37
#      38         mdl.add_constraint(con2)
# ---> 39         branch_and_cut_search()
#      40         mdl.remove_constraint(con2)
#      41     else: # solution is int
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      37
#      38         mdl.add_constraint(con2)
# ---> 39         branch_and_cut_search()
#      40         mdl.remove_constraint(con2)
#      41     else: # solution is int
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      37
#      38         mdl.add_constraint(con2)
# ---> 39         branch_and_cut_search()
#      40         mdl.remove_constraint(con2)
#      41     else: # solution is int
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      33         con2 = x[fraction_variable_index] <= 0
#      34         mdl.add_constraint(con1)
# ---> 35         branch_and_cut_search()
#      36         mdl.remove_constraint(con1)
#      37
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#      33         con2 = x[fraction_variable_index] <= 0
#      34         mdl.add_constraint(con1)
# ---> 35         branch_and_cut_search()
#      36         mdl.remove_constraint(con1)
#      37
#
# <ipython-input-829-2fe43283e32b> in branch_and_cut_search(sum_without_random)
#       1 def branch_and_cut_search(sum_without_random = 2):
#       2     global len_max_current_clique, sol, x_vars
# ----> 3     sol = mdl.solve() # нужно ли тут
#       4     if sol is None:
#       5         return
#
# c:\users\andru\appdata\local\programs\python\python37\lib\site-packages\docplex\mp\model.py in solve(self, **kwargs)
#    4144                 # if CPLEX is installed go for it
#    4145                 force_clean_before_solve = kwargs.get('clean_before_solve')
# -> 4146                 return self._solve_local(context, force_clean_before_solve, lex_timelimits, lex_mipgaps)
#    4147             elif have_credentials:
#    4148                 # no context passed as argument, no Cplex installed, try model's own context
#
# c:\users\andru\appdata\local\programs\python\python37\lib\site-packages\docplex\mp\model.py in _solve_local(self, context, force_clean_before_solve, lex_timelimits, lex_mipgaps)
#    4289             self._set_solution(None)
#    4290             print("----------------- Python exception: {}".format(str(e)))
# -> 4291             raise e
#    4292
#    4293         finally:
#
# c:\users\andru\appdata\local\programs\python\python37\lib\site-packages\docplex\mp\model.py in _solve_local(self, context, force_clean_before_solve, lex_timelimits, lex_mipgaps)
#    4271
#    4272             new_solution = self_engine.solve(self, parameters=parameters, lex_timelimits=lex_timelimits,
# -> 4273                                              lex_mipgaps=lex_mipgaps)
#    4274             has_solution = new_solution is not None
#    4275             self._set_solution(new_solution)
#
# c:\users\andru\appdata\local\programs\python\python37\lib\site-packages\docplex\mp\cplex_engine.py in solve(self, mdl, parameters, lex_mipstart, lex_timelimits, lex_mipgaps)
#    1838         # ---------------------------
#    1839         self._solve_count += 1
# -> 1840         solve_time_start = cpx.get_time()
#    1841         cpx_status = -1
#    1842         cpx_miprelgap = None
#
# c:\users\andru\appdata\local\programs\python\python37\lib\site-packages\cplex\__init__.py in get_time(self)
#    1424         The absolute value of the time stamp is not meaningful.
#    1425         """
# -> 1426         return self._env.get_time()
#    1427
#    1428     def get_dettime(self):
#
# c:\users\andru\appdata\local\programs\python\python37\lib\site-packages\cplex\_internal\__init__.py in get_time(self)
#     389     def get_time(self):
#     390         """Returns a timestamp in CPU or wallclock seconds from CPLEX."""
# --> 391         return _procedural.gettime(self._e)
#     392
#     393     def get_dettime(self):
#
# c:\users\andru\appdata\local\programs\python\python37\lib\site-packages\cplex\_internal\_procedural.py in gettime(env)
#    2979
#    2980 def gettime(env):
# -> 2981     time = CR.doublePtr()
#    2982     status = CR.CPXXgettime(env, time)
#    2983     check_status(env, status)
#
# SystemError: <built-in function delete_doublePtr> returned a result with an error set

# %%
is_int_solution()
# Out:
# True

# %%
len(x_vars)
# Out:
# 174

# %%
sol.objective_value
# Out:
# 40.85092195757482

# %%
g.is_neighbour(4,28)
# Out:
# False

# %% [markdown]
# ## замеры, проверки

# %%
def ind_sets_by_coloring_check(ind_sets:dict):


    for ind_set in ind_sets:
        for vertex_1 in ind_sets[ind_set]:
            for vertex_2 in ind_sets[ind_set]:
                if vertex_1 is not vertex_2:
                    if  g.is_neighbour(vertex_2,vertex_1):
                        print(g.is_neighbour(vertex_2,vertex_1))
    print('if pusto - OK')

# %%
for index, var in x_vars:
    print(index, var.solution_value)
# Out:
# 144 1.0
# 61 1.0
# 106 1.0
# 179 1.0
# 192 1.0
# 47 1.0
# 54 1.0
# 187 1.0
# 82 1.0
# 165 1.0
# 57 1.0
# 119 1.0
# 131 1.0
# 25 1.0
# 121 1.0
# 3 1.0
# 58 1.0
# 103 1.0
# 143 1.0
# 171 1.0
# 31 1.0
# 102 1.0

# %%
branch_and_cut_choose_branching_var()
# Out:
# 21

# %%
x[21].solution_value
# Out:
# 0.38344893861754814

# %%
mdl.number_of_constraints
# Out:
# 620

# %%
i = 0
for i in range(mdl.number_of_constraints):
    print(mdl.get_constraint_by_index(i))
    i += 1
# Out:
# x1+x3+x68+x192+x200 <= 1
# x1+x2+x38+x97+x184 <= 1
# x3+x6+x14+x77 <= 1
# x4+x7+x10+x61 <= 1
# x5+x17+x24+x49 <= 1
# x8+x9+x64+x87 <= 1
# x11+x15+x58+x113+x170 <= 1
# x1+x12+x19+x25+x196 <= 1
# x13+x21+x35 <= 1
# x16+x18+x30+x100 <= 1
# x20+x22+x40+x171+x180 <= 1
# x23+x30+x32+x39 <= 1
# x26+x27+x43+x140 <= 1
# x2+x28+x37+x95+x196 <= 1
# x29+x31+x34+x108 <= 1
# x33+x41+x69+x117 <= 1
# x36+x42+x47+x65 <= 1
# x2+x28+x44+x46+x70 <= 1
# x45+x48+x56+x133 <= 1
# x50+x57+x60+x68+x163 <= 1
# x51+x53+x54+x91+x168+x180 <= 1
# x7+x52+x62+x71 <= 1
# x33+x55+x63+x67+x146 <= 1
# x59+x66+x75+x200 <= 1
# x25+x72+x73+x95+x183 <= 1
# x74+x76+x98+x110+x129+x193 <= 1
# x78+x79+x94+x147 <= 1
# x5+x80+x85+x88+x194 <= 1
# x81+x84+x107+x123 <= 1
# x82+x83+x109 <= 1
# x70+x86+x89+x121+x137 <= 1
# x43+x90+x169+x190 <= 1
# x1+x92+x99+x101+x118 <= 1
# x93+x105+x127+x138 <= 1
# x38+x96+x112+x119 <= 1
# x102+x104+x111+x116 <= 1
# x103+x113+x136+x174 <= 1
# x106+x122+x124+x135+x159 <= 1
# x51+x114+x115 <= 1
# x120+x150+x152+x161 <= 1
# x40+x125+x126+x128+x142 <= 1
# x43+x130+x131+x164 <= 1
# x132+x140+x153+x160 <= 1
# x86+x91+x134+x143+x156 <= 1
# x119+x139+x146+x154+x198 <= 1
# x24+x42+x141+x145 <= 1
# x144+x149+x150+x162 <= 1
# x63+x148+x155+x172 <= 1
# x70+x151+x158+x189 <= 1
# x157+x167+x188 <= 1
# x165+x166+x185+x194 <= 1
# x136+x173+x175+x179 <= 1
# x105+x176+x177+x178 <= 1
# x2+x181+x182+x187 <= 1
# x69+x184+x186+x195 <= 1
# x6+x61+x191+x192 <= 1
# x33+x37+x72+x96+x197+x199 <= 1
# x12+x146+x198+x200 <= 1
# x67+x89+x113+x124 <= 1
# x47+x91+x134+x196 <= 1
# x1+x71+x72+x85+x193 <= 1
# x5+x24+x49+x145+x148 <= 1
# x54+x102+x162+x168 <= 1
# x14+x26+x50+x60+x136+x139 <= 1
# x41+x95+x123+x153+x157 <= 1
# x31+x66+x133+x167 <= 1
# x7+x30+x69+x88+x151 <= 1
# x25+x48+x76+x118+x150 <= 1
# x21+x33+x100+x198 <= 1
# x8+x9+x68+x119 <= 1
# x23+x39+x65+x105+x132 <= 1
# x37+x77+x112+x173+x180 <= 1
# x51+x111+x112+x177 <= 1
# x34+x52+x70+x145+x151+x189 <= 1
# x62+x63+x170 <= 1
# x6+x92+x143+x156 <= 1
# x74+x81+x96+x141 <= 1
# x80+x99+x147+x169 <= 1
# x17+x24+x107+x121 <= 1
# x2+x31+x38+x84 <= 1
# x40+x54+x142+x152+x185 <= 1
# x43+x131+x137 <= 1
# x5+x19+x61+x161 <= 1
# x100+x140+x181+x188+x192+x200 <= 1
# x39+x46+x78+x176+x198 <= 1
# x53+x86+x127+x134 <= 1
# x40+x125+x128+x155 <= 1
# x55+x64+x101+x186+x195 <= 1
# x72+x106+x159+x191 <= 1
# x29+x52+x69+x184 <= 1
# x11+x35+x56+x78+x89 <= 1
# x10+x66+x130+x162+x164 <= 1
# x25+x28+x87+x95+x183 <= 1
# x110+x143+x151+x158 <= 1
# x5+x98+x129+x194 <= 1
# x42+x135+x145+x154 <= 1
# x13+x83+x130+x171 <= 1
# x45+x97+x134+x146+x198 <= 1
# x85+x116+x137+x163 <= 1
# x16+x113+x166 <= 1
# x4+x40+x182+x187 <= 1
# x15+x58+x94+x110+x113 <= 1
# x102+x120+x174+x179 <= 1
# x5+x44+x108+x114+x148 <= 1
# x18+x26+x27+x82 <= 1
# x1+x45+x90+x122+x146 <= 1
# x2+x138+x196+x197 <= 1
# x36+x67+x93+x111+x146 <= 1
# x30+x57+x126+x134 <= 1
# x32+x60+x72+x117 <= 1
# x125+x178+x190+x198 <= 1
# x3+x73+x109 <= 1
# x75+x136+x139+x162+x199 <= 1
# x22+x79+x110+x172 <= 1
# x113+x144+x149 <= 1
# x41+x59+x134+x160 <= 1
# x12+x20+x104+x184+x185 <= 1
# x2+x45+x134+x146+x165 <= 1
# x29+x119+x175+x198+x200 <= 1
# x91+x115+x132+x198 <= 1
# x33+x103+x198+x200 <= 1
# x20+x29+x103 <= 1
# x18+x26+x27+x82 <= 1
# x3+x108+x199 <= 1
# x56+x59+x115+x192 <= 1
# x7+x16+x32+x149 <= 1
# x15+x72+x144+x160+x194 <= 1
# x22+x79+x110+x172 <= 1
# x73+x104+x116+x184 <= 1
# x35+x36+x165 <= 1
# x93+x140+x167+x175 <= 1
# x178+x190+x197 <= 1
# x4+x75+x142 <= 1
# x10+x54+x83+x109 <= 1
# x57+x126+x134+x158 <= 1
# x45+x81+x117+x122+x152 <= 1
# x9+x44+x64+x138 <= 1
# x98+x114+x177+x195 <= 1
# x13+x90+x101+x158 <= 1
# x102+x120+x174+x179 <= 1
# x58+x94+x110+x113+x155 <= 1
# x28+x91+x129+x154 <= 1
# x131+x132+x163+x182 <= 1
# x8+x68+x171+x191 <= 1
# x24+x42+x135+x176 <= 1
# x19+x46+x97+x112 <= 1
# x80+x111+x139+x186 <= 1
# x19+x34+x161+x166 <= 1
# x6+x41+x77+x159+x187 <= 1
# x25+x28+x87+x95+x183 <= 1
# x105+x127+x130+x136 <= 1
# x31+x74+x100+x143 <= 1
# x36+x99+x141+x150+x188 <= 1
# x11+x53+x85+x106+x193 <= 1
# x2+x48+x69+x76 <= 1
# x33+x55+x125+x181 <= 1
# x42+x65+x84+x164 <= 1
# x43+x70+x85+x121+x189 <= 1
# x61+x147+x156+x170 <= 1
# x14+x60+x78+x137 <= 1
# x86+x92+x120+x124+x157 <= 1
# x12+x40+x126+x128+x168 <= 1
# x37+x38+x96+x169+x196 <= 1
# x17+x30+x81+x107+x110 <= 1
# x25+x45+x62+x63+x67+x133 <= 1
# x32+x39+x119+x173 <= 1
# x21+x51+x123+x180 <= 1
# x50+x88+x109+x185 <= 1
# x1+x4+x12+x23+x71+x99 <= 1
# x49+x129+x145+x151 <= 1
# x5+x36+x52+x146 <= 1
# x47+x118+x134+x162 <= 1
# x66+x153+x198+x200 <= 1
# x20+x44+x56+x132+x148 <= 1
# x29+x89+x108 <= 1
# x1 >= 0
# x2 >= 0
# x3 >= 0
# x4 >= 0
# x5 >= 0
# x6 >= 0
# x7 >= 0
# x8 >= 0
# x9 >= 0
# x10 >= 0
# x11 >= 0
# x12 >= 0
# x13 >= 0
# x14 >= 0
# x15 >= 0
# x16 >= 0
# x17 >= 0
# x18 >= 0
# x19 >= 0
# x20 >= 0
# x21 >= 0
# x22 >= 0
# x23 >= 0
# x24 >= 0
# x25 >= 0
# x26 >= 0
# x27 >= 0
# x28 >= 0
# x29 >= 0
# x30 >= 0
# x31 >= 0
# x32 >= 0
# x33 >= 0
# x34 >= 0
# x35 >= 0
# x36 >= 0
# x37 >= 0
# x38 >= 0
# x39 >= 0
# x40 >= 0
# x41 >= 0
# x42 >= 0
# x43 >= 0
# x44 >= 0
# x45 >= 0
# x46 >= 0
# x47 >= 0
# x48 >= 0
# x49 >= 0
# x50 >= 0
# x51 >= 0
# x52 >= 0
# x53 >= 0
# x54 >= 0
# x55 >= 0
# x56 >= 0
# x57 >= 0
# x58 >= 0
# x59 >= 0
# x60 >= 0
# x61 >= 0
# x62 >= 0
# x63 >= 0
# x64 >= 0
# x65 >= 0
# x66 >= 0
# x67 >= 0
# x68 >= 0
# x69 >= 0
# x70 >= 0
# x71 >= 0
# x72 >= 0
# x73 >= 0
# x74 >= 0
# x75 >= 0
# x76 >= 0
# x77 >= 0
# x78 >= 0
# x79 >= 0
# x80 >= 0
# x81 >= 0
# x82 >= 0
# x83 >= 0
# x84 >= 0
# x85 >= 0
# x86 >= 0
# x87 >= 0
# x88 >= 0
# x89 >= 0
# x90 >= 0
# x91 >= 0
# x92 >= 0
# x93 >= 0
# x94 >= 0
# x95 >= 0
# x96 >= 0
# x97 >= 0
# x98 >= 0
# x99 >= 0
# x100 >= 0
# x101 >= 0
# x102 >= 0
# x103 >= 0
# x104 >= 0
# x105 >= 0
# x106 >= 0
# x107 >= 0
# x108 >= 0
# x109 >= 0
# x110 >= 0
# x111 >= 0
# x112 >= 0
# x113 >= 0
# x114 >= 0
# x115 >= 0
# x116 >= 0
# x117 >= 0
# x118 >= 0
# x119 >= 0
# x120 >= 0
# x121 >= 0
# x122 >= 0
# x123 >= 0
# x124 >= 0
# x125 >= 0
# x126 >= 0
# x127 >= 0
# x128 >= 0
# x129 >= 0
# x130 >= 0
# x131 >= 0
# x132 >= 0
# x133 >= 0
# x134 >= 0
# x135 >= 0
# x136 >= 0
# x137 >= 0
# x138 >= 0
# x139 >= 0
# x140 >= 0
# x141 >= 0
# x142 >= 0
# x143 >= 0
# x144 >= 0
# x145 >= 0
# x146 >= 0
# x147 >= 0
# x148 >= 0
# x149 >= 0
# x150 >= 0
# x151 >= 0
# x152 >= 0
# x153 >= 0
# x154 >= 0
# x155 >= 0
# x156 >= 0
# x157 >= 0
# x158 >= 0
# x159 >= 0
# x160 >= 0
# x161 >= 0
# x162 >= 0
# x163 >= 0
# x164 >= 0
# x165 >= 0
# x166 >= 0
# x167 >= 0
# x168 >= 0
# x169 >= 0
# x170 >= 0
# x171 >= 0
# x172 >= 0
# x173 >= 0
# x174 >= 0
# x175 >= 0
# x176 >= 0
# x177 >= 0
# x178 >= 0
# x179 >= 0
# x180 >= 0
# x181 >= 0
# x182 >= 0
# x183 >= 0
# x184 >= 0
# x185 >= 0
# x186 >= 0
# x187 >= 0
# x188 >= 0
# x189 >= 0
# x190 >= 0
# x191 >= 0
# x192 >= 0
# x193 >= 0
# x194 >= 0
# x195 >= 0
# x196 >= 0
# x197 >= 0
# x198 >= 0
# x199 >= 0
# x200 >= 0
# x1+x49+x117+x127 <= 1
# x22+x69+x141 <= 1
# x9+x62+x115 <= 1
# x144+x165+x170+x174 <= 1
# x57+x89+x115+x158 <= 1
# x48+x98+x154 <= 1
# x50+x133+x153+x167+x185 <= 1
# x27+x62+x67+x80 <= 1
# x49+x61+x149 <= 1
# x9+x58+x189+x191 <= 1
# x47+x65+x129+x161 <= 1
# x21+x62+x92+x187+x189 <= 1
# x4+x39+x71+x161+x182 <= 1
# x75+x88+x127+x143 <= 1
# x108+x149+x156+x181 <= 1
# x23+x128+x132+x152+x183 <= 1
# x61+x118+x124+x133 <= 1
# x35+x80+x169+x178 <= 1
# x49+x82+x142+x176 <= 1
# x127+x166+x199 <= 1
# x9+x47+x83+x181 <= 1
# x35+x52+x87 <= 1
# x60+x63+x103+x117 <= 1
# x17+x48+x67+x172 <= 1
# x52+x69+x186+x196 <= 1
# x50+x146+x147+x157+x173 <= 1
# x79+x168+x195 <= 1
# x46+x52+x68+x131+x155 <= 1
# x8+x9+x90+x168+x191 <= 1
# x30+x38+x80+x123 <= 1
# x10+x44+x73+x118+x151 <= 1
# x87+x109+x196 <= 1
# x31+x49+x79+x166 <= 1
# x13+x101+x179+x182 <= 1
# x15+x58+x141+x154 <= 1
# x33+x55+x137+x163+x190 <= 1
# x46+x74+x176+x182 <= 1
# x12+x74+x102+x146+x167 <= 1
# x79+x84+x98+x118 <= 1
# x11+x63+x68+x114+x172 <= 1
# x39+x66+x78+x153 <= 1
# x44+x61+x65+x150+x162 <= 1
# x56+x84+x118+x123+x188 <= 1
# x19+x85+x107+x168+x187 <= 1
# x48+x106+x125+x141+x157 <= 1
# x12+x117+x146+x164+x167 <= 1
# x47+x76+x148+x165+x186 <= 1
# x67+x107+x126+x178 <= 1
# x29+x53+x135+x144 <= 1
# x18+x86+x103+x143 <= 1
# x21+x51+x81+x143+x173 <= 1
# x86+x127+x134+x191 <= 1
# x3+x16+x47+x118 <= 1
# x32+x61+x77+x105 <= 1
# x9+x73+x138+x143+x154 <= 1
# x47+x48+x91+x156 <= 1
# x27+x64+x102+x167 <= 1
# x35+x84+x92+x116 <= 1
# x62+x159+x187+x196+x198 <= 1
# x15+x32+x68 <= 1
# x15+x100+x109 <= 1
# x19+x22+x75+x102 <= 1
# x27+x57+x61+x158 <= 1
# x29+x69+x83 <= 1
# x6+x103+x126 <= 1
# x12+x23+x113+x124+x156+x170 <= 1
# x69+x104+x111+x112 <= 1
# x97+x156+x167+x175 <= 1
# x31+x42+x43+x91+x193 <= 1
# x17+x24+x49+x172 <= 1
# x26+x60+x66+x147+x164 <= 1
# x5+x30+x129+x134+x146+x176 <= 1
# x53+x62+x133+x134 <= 1
# x41+x77+x112+x190 <= 1
# x95+x120+x133+x177 <= 1
# x14+x123+x150+x164 <= 1
# x59+x128+x155 <= 1
# x8+x71+x145+x192 <= 1
# x38+x47+x131+x169+x196 <= 1
# x4+x28+x99+x147 <= 1
# x13+x21+x65+x106 <= 1
# x35+x48+x84+x174 <= 1
# x21+x36+x83+x177 <= 1
# x79+x120+x172+x195 <= 1
# x94+x113+x128+x155+x172 <= 1
# x59+x77+x134+x191 <= 1
# x42+x58+x113+x123 <= 1
# x6+x12+x36+x99+x170 <= 1
# x97+x127+x136+x138+x146 <= 1
# x8+x93+x129+x166 <= 1
# x12+x69+x82+x196 <= 1
# x32+x66+x133+x149 <= 1
# x82+x89+x109+x169+x196 <= 1
# x100+x123+x130+x166+x179 <= 1
# x58+x73+x74+x167+x182 <= 1
# x13+x35+x89+x115+x171 <= 1
# x80+x108+x140+x175+x187 <= 1
# x83+x150+x155+x181 <= 1
# x17+x64+x138+x155 <= 1
# x31+x80+x113+x191 <= 1
# x13+x21+x65+x173 <= 1
# x53+x103+x117+x161 <= 1
# x17+x30+x34+x80+x121+x140 <= 1
# x57+x79+x142 <= 1
# x12+x19+x46+x156 <= 1
# x62+x65+x106+x191 <= 1
# x2+x18+x192+x197 <= 1
# x4+x24+x40+x57 <= 1
# x48+x57+x96+x126 <= 1
# x5+x43+x88+x114+x146 <= 1
# x8+x26+x88+x142 <= 1
# x18+x63+x133+x153 <= 1
# x8+x60+x71+x90+x171 <= 1
# x2+x18+x131+x169 <= 1
# x19+x51+x123+x180 <= 1
# x51+x66+x173+x189 <= 1
# x64+x70+x105+x153+x178 <= 1
# x78+x127+x177+x186 <= 1
# x11+x44+x56+x191 <= 1
# x4+x7+x87+x97 <= 1
# x76+x98+x118+x159 <= 1
# x37+x103+x178 <= 1
# x16+x32+x119+x154 <= 1
# x6+x18+x100+x174+x192 <= 1
# x32+x61+x133+x134+x158 <= 1
# x12+x40+x49+x68+x89+x200 <= 1
# x3+x165+x199 <= 1
# x31+x40+x49+x124 <= 1
# x66+x101+x138+x167 <= 1
# x59+x76+x87+x164 <= 1
# x6+x62+x159+x191 <= 1
# x29+x53+x103 <= 1
# x64+x88+x125+x178+x190 <= 1
# x27+x78+x120+x179 <= 1
# x37+x39+x71+x116 <= 1
# x43+x65+x121+x135 <= 1
# x3+x29+x100+x109 <= 1
# x11+x18+x53+x177 <= 1
# x32+x51+x66+x173 <= 1
# x35+x87+x133+x153+x185 <= 1
# x6+x18+x103+x174+x198 <= 1
# x3+x7+x48+x118+x125 <= 1
# x41+x62+x84+x92+x194 <= 1
# x8+x26+x96+x153+x197 <= 1
# x41+x106+x131+x141+x159 <= 1
# x16+x137+x160 <= 1
# x52+x69+x82+x160 <= 1
# x16+x18+x86+x200 <= 1
# x94+x98+x114+x127+x177 <= 1
# x69+x76+x93+x127 <= 1
# x14+x80+x86+x113+x123 <= 1
# x12+x66+x111+x147+x200 <= 1
# x31+x66+x166+x179 <= 1
# x147+x149+x156+x173 <= 1
# x1+x131+x141+x165 <= 1
# x81+x109+x152+x160 <= 1
# x59+x148+x155+x160 <= 1
# x68+x165+x191 <= 1
# x18+x63+x97+x164 <= 1
# x56+x134+x165+x166+x191 <= 1
# x92+x188+x190+x197 <= 1
# x78+x137+x190+x196 <= 1
# x66+x85+x116+x188 <= 1
# x29+x50+x93+x109+x145 <= 1
# x9+x59+x88+x90+x119 <= 1
# x5+x66+x108+x113+x149 <= 1
# x24+x49+x60+x123+x179 <= 1
# x5+x44+x54+x118+x162 <= 1
# x116+x170+x188+x199 <= 1
# x14+x86+x102+x137+x146 <= 1
# x14+x67+x80+x113+x161 <= 1
# x39+x84+x98+x107+x116 <= 1
# x22+x31+x74+x129+x141 <= 1
# x75+x83+x111+x177 <= 1
# x1+x38+x47+x82+x126 <= 1
# x54+x83+x105+x178 <= 1
# x12+x102+x111+x146+x147 <= 1
# x16+x142+x160 <= 1
# x33+x69+x117+x127 <= 1
# x72+x165+x170+x174+x199 <= 1
# x101+x102+x147+x163+x182 <= 1
# x51+x77+x81+x112+x115 <= 1
# x19+x85+x157+x187+x194 <= 1
# x10+x54+x132+x192 <= 1
# x49+x129+x151+x170 <= 1
# x78+x132+x153+x163+x198 <= 1
# x2+x48+x95+x181+x183 <= 1
# x19+x28+x87+x97 <= 1
# x3+x16+x67+x128+x142 <= 1
# x52+x69+x144+x160 <= 1
# x45+x63+x116+x117+x146 <= 1
# x19+x132+x157 <= 1
# x5+x71+x80+x161 <= 1
# x31+x122+x129+x154 <= 1
# x94+x163+x167+x189 <= 1
# x5+x36+x137+x146+x176 <= 1
# x2+x31+x38+x167+x196 <= 1
# x119+x144+x154+x192 <= 1
# x40+x57+x126+x142+x184 <= 1
# x154+x175+x185+x198 <= 1
# x78+x127+x132+x163 <= 1
# x13+x49+x89+x179+x200 <= 1
# x24+x40+x49+x134+x176 <= 1
# x1+x49+x68+x165 <= 1
# x4+x21+x65+x161 <= 1
# x2+x36+x87+x97+x189 <= 1
# x32+x61+x70+x150+x158 <= 1
# x104+x111+x116+x151 <= 1
# x41+x59+x152+x160 <= 1
# x27+x62+x65+x132 <= 1
# x118+x124+x139+x173+x180 <= 1
# x17+x28+x102+x116 <= 1
# x24+x57+x184+x185+x195 <= 1
# x12+x69+x107+x111+x183 <= 1
# x17+x69+x107+x183 <= 1
# x54+x108+x156+x175 <= 1
# x45+x46+x159+x198 <= 1
# x69+x104+x111+x151 <= 1
# x77+x107+x121+x159+x169 <= 1
# x27+x43+x167+x178 <= 1
# x13+x90+x122+x158 <= 1
# x104+x135+x151+x176 <= 1
# x49+x151+x165+x170 <= 1
# x17+x30+x49+x75 <= 1
# x8+x23+x71+x90+x191 <= 1
# x5+x49+x108+x148+x170 <= 1
# x38+x76+x80+x175 <= 1
# x14+x16+x60+x90+x119+x137 <= 1
# x59+x128+x155 <= 1
# x59+x128+x155 <= 1
# x59 >= 1
# x5+x59+x80+x161 <= 1
# x21+x30+x59+x98 <= 1
# x59+x108+x140 <= 1
# x50+x59+x74+x173 <= 1
# x24+x139+x146+x158 <= 1
# x59+x93+x133 <= 1
# x59+x196 <= 1
# x59+x163+x174 <= 1
# x114 >= 1
# x14+x46+x113+x114 <= 1
# x37+x38+x114+x168 <= 1
# x10+x114+x142+x185 <= 1
# x4+x24+x61+x114 <= 1
# x114+x122+x181+x183 <= 1
# x95+x107+x114 <= 1
# x60+x71+x72+x145 <= 1
# x105+x114+x178 <= 1
# x114+x130 <= 1
# x59+x96 <= 1
# x54+x62+x67+x89 <= 1
# x114+x141+x170 <= 1
# x55+x114 <= 1
# x114+x182 <= 1
# x8+x60+x71+x145 <= 1
# x12+x59 <= 1
# x60+x71+x171+x180 <= 1
# x121 >= 1
# x81+x121+x147 <= 1
# x39+x78+x121+x176+x198 <= 1
# x18+x100+x121+x143 <= 1
# x1+x121+x132 <= 1
# x40+x45+x121+x149 <= 1
# x58+x121 <= 1
# x97+x121+x199 <= 1
# x7+x121 <= 1
# x23+x153+x156 <= 1
# x54+x102+x120+x162 <= 1
# x33 >= 1
# x33+x64+x112 <= 1
# x25+x33+x124 <= 1
# x33+x166+x186 <= 1
# x33+x144+x162 <= 1
# x26+x33 <= 1
# x20 >= 1
# x20+x23+x131 <= 1
# x20+x54+x120 <= 1
# x20+x62 <= 1
# x20+x109 <= 1
# x20+x158 <= 1
# x8+x123+x153 <= 1
# x175 >= 1
# x6 >= 1
# x6+x48+x57 <= 1
# x6+x79 <= 1
# x6+x101+x102 <= 1
# x6+x116 <= 1
# x6+x82 <= 1
# x47+x153+x157 <= 1
# x47+x129+x153 <= 1
# x13 >= 1
# x42 >= 1
# x15+x153+x157 <= 1
# x2 >= 1

# %% [markdown]
# x2+x42+x111

# %%
x[14].solution_value
# Out:
# ---------------------------------------------------------------------------
# DOcplexException                          Traceback (most recent call last)
# <ipython-input-627-64f75fe948de> in <module>
# ----> 1 x[14].solution_value
#
# c:\users\andru\appdata\local\programs\python\python37\lib\site-packages\docplex\mp\linear.py in solution_value(self)
#     249
#     250         """
# --> 251         self._check_model_has_solution()
#     252         return self._get_solution_value()
#     253
#
# c:\users\andru\appdata\local\programs\python\python37\lib\site-packages\docplex\mp\basic.py in _check_model_has_solution(self)
#     112
#     113     def _check_model_has_solution(self):
# --> 114         self.model.check_has_solution()
#     115
#     116     def fatal(self, msg, *args):
#
# c:\users\andru\appdata\local\programs\python\python37\lib\site-packages\docplex\mp\model.py in check_has_solution(self)
#    4686                 self.fatal("Model<{0}> has not been solved yet", self.name)
#    4687             else:
# -> 4688                 self.fatal("Model<{0}> did not solve successfully", self.name)
#    4689
#    4690     def add_mip_start(self, mip_start_sol, effort_level=None):
#
# c:\users\andru\appdata\local\programs\python\python37\lib\site-packages\docplex\mp\model.py in fatal(self, msg, *args)
#     882
#     883     def fatal(self, msg, *args):
# --> 884         self._error_handler.fatal(msg, args)
#     885
#     886     def fatal_ce_limits(self, *args):
#
# c:\users\andru\appdata\local\programs\python\python37\lib\site-packages\docplex\mp\error_handler.py in fatal(self, msg, args)
#     208         resolved_message = resolve_pattern(msg, args)
#     209         docplex_error_stop_here()
# --> 210         raise DOcplexException(resolved_message)
#     211
#     212     def fatal_limits_exceeded(self):
#
# DOcplexException: Model<max clique> did not solve successfully

# %% [markdown]
# ##def is_a_clique():
# x_vars == vertex_names? вплане смысла
